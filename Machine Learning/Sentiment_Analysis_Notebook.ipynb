# %% [markdown]
# # Sentiment Analysis: Weighted Scores + TextBlob Polarity

# %%
import pandas as pd
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob

# Downloads
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/maryamkhalid/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/maryamkhalid/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/maryamkhalid/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/maryamkhalid/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ## Step 1: Load the Dataset

# %%
df = pd.read_csv("supset1_NLP.csv")
df.head()
# Out:
#    SURVEYR       descrip_E QUESTION  \
# 0     2022  Public Service      Q01
# 1     2022   Health Canada      Q01
# 2     2020  Public Service      Q01
# 3     2020   Health Canada      Q01
# 4     2022  Public Service      Q02
#
#                                              TITLE_E  \
# 0  Question 1. I have the tools, technology and e...
# 1  Question 1. I have the tools, technology and e...
# 2  Question 1. I have the tools, technology and e...
# 3  Question 1. I have the tools, technology and e...
# 4  Question 2. The material and tools provided fo...
#
#                            ANSWER1  \
# 0   forty three percent voted for
# 1   thirty nine percent voted for
# 2  thirty seven percent voted for
# 3  thirty eight percent voted for
# 4  seventy five percent voted for
#
#                                       Strongly Agree  \
# 0                   I have all the equipment I need.
# 1                   I have all the equipment I need.
# 2                   I have all the equipment I need.
# 3                   I have all the equipment I need.
# 4  All tools are available in my preferred offici...
#
#                          ANSWER2  \
# 0   forty one percent voted for
# 1  forty four percent voted for
# 2  forty five percent voted for
# 3   forty six percent voted for
# 4    eighteen percent voted for
#
#                                       Somewhat Agree  \
# 0               I have most of the equipment I need.
# 1               I have most of the equipment I need.
# 2               I have most of the equipment I need.
# 3               I have most of the equipment I need.
# 4  Most tools are available in my preferred offic...
#
#                     ANSWER3  \
# 0   four percent voted for
# 1   four percent voted for
# 2   four percent voted for
# 3   four percent voted for
# 4  three percent voted for
#
#                           Neither Agree Nor Disagree                  ANSWER4  \
# 0    I am unsure if I have all the equipment I need.  nine percent voted for
# 1    I am unsure if I have all the equipment I need.   ten percent voted for
# 2    I am unsure if I have all the equipment I need.   ten percent voted for
# 3    I am unsure if I have all the equipment I need.   ten percent voted for
# 4  I am neutral about the availability of tools i...   two percent voted for
#
#                                    Somewhat Disagree  \
# 0                   I lack some necessary equipment.
# 1                   I lack some necessary equipment.
# 2                   I lack some necessary equipment.
# 3                   I lack some necessary equipment.
# 4  Some tools are not available in my preferred o...
#
#                     ANSWER5  \
# 0   four percent voted for
# 1   four percent voted for
# 2  three percent voted for
# 3    two percent voted for
# 4    one percent voted for
#
#                                    Strongly Disagree  \
# 0                I do not have the equipment I need.
# 1                I do not have the equipment I need.
# 2                I do not have the equipment I need.
# 3                I do not have the equipment I need.
# 4  Tools are not available in my preferred offici...
#
#                                ANSWER6    Don't Know                  ANSWER7  \
# 0  zero percent voted for this option.  I am unsure.  zero percent voted for
# 1  zero percent voted for this option.  I am unsure.  zero percent voted for
# 2  zero percent voted for this option.  I am unsure.  zero percent voted for
# 3  zero percent voted for this option.  I am unsure.  zero percent voted for
# 4  zero percent voted for this option.  I am unsure.   one percent voted for
#
#                Not Applicable
# 0  This does not apply to me.
# 1  This does not apply to me.
# 2  This does not apply to me.
# 3  This does not apply to me.
# 4  This does not apply to me.

# %% [markdown]
# ## Step 2: Combine Columns into Full Text

# %%
columns_to_combine = ['QUESTION', 'TITLE_E', 'ANSWER1', 'Strongly Agree', 'ANSWER2', 'Somewhat Agree',
                      'ANSWER3', 'Neither Agree Nor Disagree', 'ANSWER4', 'Somewhat Disagree', 
                      'ANSWER5', 'Strongly Disagree']
df['Combined_Text'] = df[columns_to_combine].astype(str).agg(' '.join, axis=1)

# %% [markdown]
# ## Step 3: Define NLP Preprocessing Function

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    tokens = [t for t in tokens if t not in string.punctuation]
    tokens = [t for t in tokens if t not in stop_words]
    tokens = [lemmatizer.lemmatize(t, pos='v') for t in tokens]
    return ' '.join(tokens)

# %% [markdown]
# ## Step 4: Apply Preprocessing and Polarity

# %%
df['Cleaned_Text'] = df['Combined_Text'].apply(preprocess_text)
df['Polarity_Score'] = df['Cleaned_Text'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# ## Step 5: Extract Numeric Percentages and Calculate Weighted Score

# %%
# Manual word-to-number mapping
word_to_num = {
    'zero': 0, 'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5,
    'six': 6, 'seven': 7, 'eight': 8, 'nine': 9, 'ten': 10,
    'eleven': 11, 'twelve': 12, 'thirteen': 13, 'fourteen': 14,
    'fifteen': 15, 'sixteen': 16, 'seventeen': 17, 'eighteen': 18,
    'nineteen': 19, 'twenty': 20, 'twenty one': 21, 'twenty two': 22,
    'twenty three': 23, 'twenty four': 24, 'twenty five': 25,
    'twenty six': 26, 'twenty seven': 27, 'twenty eight': 28,
    'twenty nine': 29, 'thirty': 30, 'thirty one': 31, 'thirty two': 32,
    'thirty three': 33, 'thirty four': 34, 'thirty five': 35,
    'thirty six': 36, 'thirty seven': 37, 'thirty eight': 38,
    'thirty nine': 39, 'forty': 40, 'forty one': 41, 'forty two': 42,
    'forty three': 43, 'forty four': 44, 'forty five': 45,
    'forty six': 46, 'forty seven': 47, 'forty eight': 48,
    'forty nine': 49, 'fifty': 50, 'seventy five': 75
}

def extract_percent(text):
    if not isinstance(text, str):
        return 0
    return word_to_num.get(text.lower().replace("percent voted for", "").strip(), 0)

for i in range(1, 6):
    col = f'ANSWER{i}'
    df[f'percent_{col.lower()}'] = df[col].apply(extract_percent)

df['Weighted_Score'] = (
    df['percent_answer1'] * 2 +
    df['percent_answer2'] * 1 +
    df['percent_answer3'] * 0 +
    df['percent_answer4'] * -1 +
    df['percent_answer5'] * -2
)

# %% [markdown]
# ## Step 6: Calculate Sentiment Score

# %%
# Normalize Weighted_Score to [-1, 1] scale
df['Weighted_Score_Norm'] = (df['Weighted_Score'] - df['Weighted_Score'].min()) / (
    df['Weighted_Score'].max() - df['Weighted_Score'].min()) * 2 - 1

# Hybrid score: 70% weighted, 30% polarity
df['Hybrid_Score'] = 0.7 * df['Weighted_Score_Norm'] + 0.3 * df['Polarity_Score']

# Final sentiment classification
def classify_sentiment(score):
    if score > 0.1:
        return 'Positive'
    elif score < -0.1:
        return 'Negative'
    else:
        return 'Neutral'

df['Hybrid_Sentiment'] = df['Hybrid_Score'].apply(classify_sentiment)
df[['Weighted_Score', 'Polarity_Score', 'Hybrid_Score', 'Hybrid_Sentiment']].head()
# Out:
#    Weighted_Score  Polarity_Score  Hybrid_Score Hybrid_Sentiment
# 0             110             0.0      0.350000         Positive
# 1             104             0.0      0.317692         Positive
# 2             103             0.0      0.312308         Positive
# 3             108             0.0      0.339231         Positive
# 4             164             0.4      0.760769         Positive

# %%
df.head()
# Out:
#    SURVEYR       descrip_E QUESTION  \
# 0     2022  Public Service      Q01
# 1     2022   Health Canada      Q01
# 2     2020  Public Service      Q01
# 3     2020   Health Canada      Q01
# 4     2022  Public Service      Q02
#
#                                              TITLE_E  \
# 0  Question 1. I have the tools, technology and e...
# 1  Question 1. I have the tools, technology and e...
# 2  Question 1. I have the tools, technology and e...
# 3  Question 1. I have the tools, technology and e...
# 4  Question 2. The material and tools provided fo...
#
#                            ANSWER1  \
# 0   forty three percent voted for
# 1   thirty nine percent voted for
# 2  thirty seven percent voted for
# 3  thirty eight percent voted for
# 4  seventy five percent voted for
#
#                                       Strongly Agree  \
# 0                   I have all the equipment I need.
# 1                   I have all the equipment I need.
# 2                   I have all the equipment I need.
# 3                   I have all the equipment I need.
# 4  All tools are available in my preferred offici...
#
#                          ANSWER2  \
# 0   forty one percent voted for
# 1  forty four percent voted for
# 2  forty five percent voted for
# 3   forty six percent voted for
# 4    eighteen percent voted for
#
#                                       Somewhat Agree  \
# 0               I have most of the equipment I need.
# 1               I have most of the equipment I need.
# 2               I have most of the equipment I need.
# 3               I have most of the equipment I need.
# 4  Most tools are available in my preferred offic...
#
#                     ANSWER3  \
# 0   four percent voted for
# 1   four percent voted for
# 2   four percent voted for
# 3   four percent voted for
# 4  three percent voted for
#
#                           Neither Agree Nor Disagree  ... Polarity_Score  \
# 0    I am unsure if I have all the equipment I need.  ...            0.0
# 1    I am unsure if I have all the equipment I need.  ...            0.0
# 2    I am unsure if I have all the equipment I need.  ...            0.0
# 3    I am unsure if I have all the equipment I need.  ...            0.0
# 4  I am neutral about the availability of tools i...  ...            0.4
#
#   percent_answer1 percent_answer2 percent_answer3 percent_answer4  \
# 0              43              41               4               9
# 1              39              44               4              10
# 2              37              45               4              10
# 3              38              46               4              10
# 4              75              18               3               2
#
#   percent_answer5 Weighted_Score Weighted_Score_Norm Hybrid_Score  \
# 0               4            110            0.500000     0.350000
# 1               4            104            0.453846     0.317692
# 2               3            103            0.446154     0.312308
# 3               2            108            0.484615     0.339231
# 4               1            164            0.915385     0.760769
#
#   Hybrid_Sentiment
# 0         Positive
# 1         Positive
# 2         Positive
# 3         Positive
# 4         Positive
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Step 7: Save Final Output

# %%
df.to_csv("sentiment_results.csv", index=False)
print("Saved to sentiment_results.csv")
# Out:
# Saved to sentiment_results.csv
