# %%
import pandas as pd

# %%
# Import the data
data = pd.read_csv('subset-1-2022_2023-pses-open-dataset-with-labels_sous-ensemble-1-ensemble-de-donnees-ouvertes-du.csv', encoding='latin-1')
# Out:
# <ipython-input-2-55710bcd6a46>:2: DtypeWarning: Columns (19,21,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('subset-1-2022_2023-pses-open-dataset-with-labels_sous-ensemble-1-ensemble-de-donnees-ouvertes-du.csv', encoding='latin-1')

# %%
data.shape
# Out:
# (56088, 35)

# %%
# show head of the data, and show all the columns
pd.set_option('display.max_columns', None)
data.head()
# Out:
#    LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR  BYCOND  \
# 0         0         0         0         0         0     2022     NaN
# 1         1         0         0         0         0     2022     NaN
# 2         2         0         0         0         0     2022     NaN
# 3         3         0         0         0         0     2022     NaN
# 4         4         0         0         0         0     2022     NaN
#
#                                   descrip_E  \
# 0                            Public Service
# 1                     Canada Revenue Agency
# 2  Employment and Social Development Canada
# 3            Department of National Defence
# 4               Correctional Service Canada
#
#                                descrip_F  DEMCODE QUESTION  \
# 0                      Fonction publique      NaN      Q01
# 1             Agence du revenu du Canada      NaN      Q01
# 2  Emploi et Développement social Canada      NaN      Q01
# 3      Ministère de la Défense nationale      NaN      Q01
# 4           Service correctionnel Canada      NaN      Q01
#
#                                              TITLE_E  \
# 0  Question 1. I have the tools, technology and e...
# 1  Question 1. I have the tools, technology and e...
# 2  Question 1. I have the tools, technology and e...
# 3  Question 1. I have the tools, technology and e...
# 4  Question 1. I have the tools, technology and e...
#
#                                              TITLE_F ANSWER1 ANSWER2 ANSWER3  \
# 0  Question 1. Je dispose des outils, de la techn...      43      41       4
# 1  Question 1. Je dispose des outils, de la techn...      56      36       2
# 2  Question 1. Je dispose des outils, de la techn...      53      36       3
# 3  Question 1. Je dispose des outils, de la techn...      31      44       5
# 4  Question 1. Je dispose des outils, de la techn...      22      46       6
#
#   ANSWER4 ANSWER5 ANSWER6 ANSWER7 MOST_POSITIVE_OR_LEAST_NEGATIVE  \
# 0       9       4       0       0                              84
# 1       4       1       0       0                              92
# 2       6       2       0       0                              89
# 3      13       6       0       0                              75
# 4      15      10       0       0                              69
#
#   NEUTRAL_OR_MIDDLE_CATEGORY MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5  \
# 0                          4                              12    84    4.1
# 1                          2                               6    92   4.41
# 2                          3                               8    89   4.33
# 3                          5                              19    75   3.81
# 4                          6                              25    69   3.56
#
#   SCORE100  ANSCOUNT                                    DEPT_E  \
# 0       78  189360.0                            Public Service
# 1       85   35735.0                     Canada Revenue Agency
# 2       83   21230.0  Employment and Social Development Canada
# 3       70   12665.0            Department of National Defence
# 4       64    6685.0               Correctional Service Canada
#
#                                   DEPT_F  INDICATORID INDICATORENG  \
# 0                      Fonction publique            4    Workplace
# 1             Agence du revenu du Canada            4    Workplace
# 2  Emploi et Développement social Canada            4    Workplace
# 3      Ministère de la Défense nationale            4    Workplace
# 4           Service correctionnel Canada            4    Workplace
#
#         INDICATORFRA  SUBINDICATORID                     SUBINDICATORENG  \
# 0  Milieu de travail            14.0  Physical environment and equipment
# 1  Milieu de travail            14.0  Physical environment and equipment
# 2  Milieu de travail            14.0  Physical environment and equipment
# 3  Milieu de travail            14.0  Physical environment and equipment
# 4  Milieu de travail            14.0  Physical environment and equipment
#
#                         SUBINDICATORFRA
# 0  Environnement physique et équipement
# 1  Environnement physique et équipement
# 2  Environnement physique et équipement
# 3  Environnement physique et équipement
# 4  Environnement physique et équipement

# %%
data.tail()
# Out:
#        LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR  BYCOND  \
# 56083        47         0         0         0         0     2019     NaN
# 56084        50         0         0         0         0     2019     NaN
# 56085        52         0         0         0         0     2019     NaN
# 56086        53         0         0         0         0     2019     NaN
# 56087        54         0         0         0         0     2019     NaN
#
#                                      descrip_E  \
# 56083       Impact Assessment Agency of Canada
# 56084         National Research Council Canada
# 56085  Office of the Auditor General of Canada
# 56086                     Public Safety Canada
# 56087           Canadian Transportation Agency
#
#                                       descrip_F  DEMCODE QUESTION  \
# 56083    Agence d'évaluation d'impact du Canada      NaN     Q72i
# 56084     Conseil national de recherches Canada      NaN     Q72i
# 56085  Bureau du vérificateur général du Canada      NaN     Q72i
# 56086                  Sécurité publique Canada      NaN     Q72i
# 56087           Office des transports du Canada      NaN     Q72i
#
#                                                  TITLE_E  \
# 56083  Question 72i. Overall, to what extent do the f...
# 56084  Question 72i. Overall, to what extent do the f...
# 56085  Question 72i. Overall, to what extent do the f...
# 56086  Question 72i. Overall, to what extent do the f...
# 56087  Question 72i. Overall, to what extent do the f...
#
#                                                  TITLE_F ANSWER1 ANSWER2  \
# 56083  Question 72i. Dans l'ensemble, dans quelle mes...      26      36
# 56084  Question 72i. Dans l'ensemble, dans quelle mes...      31      32
# 56085  Question 72i. Dans l'ensemble, dans quelle mes...      29      34
# 56086  Question 72i. Dans l'ensemble, dans quelle mes...      26      29
# 56087  Question 72i. Dans l'ensemble, dans quelle mes...      38      30
#
#       ANSWER3 ANSWER4 ANSWER5 ANSWER6 ANSWER7 MOST_POSITIVE_OR_LEAST_NEGATIVE  \
# 56083      21      12       5       1       0                              63
# 56084      20      11       5       0       1                              64
# 56085      22       9       5       0       1                              64
# 56086      19      14      11       0       0                              56
# 56087      15       9       7       0       0                              69
#
#       NEUTRAL_OR_MIDDLE_CATEGORY MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5  \
# 56083                         21                              16    16   3.68
# 56084                         20                              16    16   3.74
# 56085                         22                              13    13   3.76
# 56086                         19                              25    25   3.45
# 56087                         15                              16    16   3.84
#
#       SCORE100  ANSCOUNT                                   DEPT_E  \
# 56083       67     348.0       Impact Assessment Agency of Canada
# 56084       69    2454.0         National Research Council Canada
# 56085       69     427.0  Office of the Auditor General of Canada
# 56086       61     769.0                     Public Safety Canada
# 56087       71     197.0           Canadian Transportation Agency
#
#                                          DEPT_F  INDICATORID  \
# 56083    Agence d'évaluation d'impact du Canada            5
# 56084     Conseil national de recherches Canada            5
# 56085  Bureau du vérificateur général du Canada            5
# 56086                  Sécurité publique Canada            5
# 56087           Office des transports du Canada            5
#
#                INDICATORENG                    INDICATORFRA  SUBINDICATORID  \
# 56083  Workplace well-being  Bien-être en milieu de travail            22.0
# 56084  Workplace well-being  Bien-être en milieu de travail            22.0
# 56085  Workplace well-being  Bien-être en milieu de travail            22.0
# 56086  Workplace well-being  Bien-être en milieu de travail            22.0
# 56087    Workplace well-bei                             NaN             NaN
#
#            SUBINDICATORENG        SUBINDICATORFRA
# 56083  Work-related stress  Stress lié au travail
# 56084  Work-related stress  Stress lié au travail
# 56085  Work-related stress  Stress lié au travail
# 56086  Work-related stress  Stress lié au travail
# 56087                  NaN                    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56088 entries, 0 to 56087
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         56088 non-null  int64
#  1   LEVEL2ID                         56088 non-null  int64
#  2   LEVEL3ID                         56088 non-null  int64
#  3   LEVEL4ID                         56088 non-null  int64
#  4   LEVEL5ID                         56088 non-null  int64
#  5   SURVEYR                          56088 non-null  int64
#  6   BYCOND                           0 non-null      float64
#  7   descrip_E                        56088 non-null  object
#  8   descrip_F                        56088 non-null  object
#  9   DEMCODE                          0 non-null      float64
#  10  QUESTION                         56088 non-null  object
#  11  TITLE_E                          56088 non-null  object
#  12  TITLE_F                          56088 non-null  object
#  13  ANSWER1                          44952 non-null  object
#  14  ANSWER2                          44952 non-null  object
#  15  ANSWER3                          44952 non-null  object
#  16  ANSWER4                          44952 non-null  object
#  17  ANSWER5                          44952 non-null  object
#  18  ANSWER6                          44952 non-null  object
#  19  ANSWER7                          44952 non-null  object
#  20  MOST_POSITIVE_OR_LEAST_NEGATIVE  44952 non-null  object
#  21  NEUTRAL_OR_MIDDLE_CATEGORY       44952 non-null  object
#  22  MOST_NEGATIVE_OR_LEAST_POSITIVE  44952 non-null  object
#  23  AGREE                            44952 non-null  object
#  24  SCORE5                           44952 non-null  object
#  25  SCORE100                         44952 non-null  object
#  26  ANSCOUNT                         42625 non-null  float64
#  27  DEPT_E                           56088 non-null  object
#  28  DEPT_F                           56088 non-null  object
#  29  INDICATORID                      56088 non-null  int64
#  30  INDICATORENG                     56088 non-null  object
#  31  INDICATORFRA                     56087 non-null  object
#  32  SUBINDICATORID                   56087 non-null  float64
#  33  SUBINDICATORENG                  56087 non-null  object
#  34  SUBINDICATORFRA                  56087 non-null  object
# dtypes: float64(4), int64(7), object(24)
# memory usage: 15.0+ MB

# %%
# dropping the french columns: descrip_F,TITLE_F ,DEPT_F ,SUBINDICATORFRA,INDICATORFRA AND SAVE IT IN A NEW datafarme call ot df_HC
df = data.drop(columns=['descrip_F', 'TITLE_F', 'DEPT_F', 'SUBINDICATORFRA', 'INDICATORFRA'])

# %%
# extract the df to be equal only where DEPT_E = 'Health Canada'or 'Public Service' or'Public Health Agency of Canada'
df = df[df['DEPT_E'].isin(['Health Canada', 'Public Service', 'Public Health Agency of Canada'])]
df.head()
# Out:
#     LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR  BYCOND  \
# 0          0         0         0         0         0     2022     NaN
# 6          6         0         0         0         0     2022     NaN
# 49        70         0         0         0         0     2022     NaN
# 92         0         0         0         0         0     2020     NaN
# 98         6         0         0         0         0     2020     NaN
#
#                          descrip_E  DEMCODE QUESTION  \
# 0                   Public Service      NaN      Q01
# 6                    Health Canada      NaN      Q01
# 49  Public Health Agency of Canada      NaN      Q01
# 92                  Public Service      NaN      Q01
# 98                   Health Canada      NaN      Q01
#
#                                               TITLE_E ANSWER1 ANSWER2 ANSWER3  \
# 0   Question 1. I have the tools, technology and e...      43      41       4
# 6   Question 1. I have the tools, technology and e...      39      44       4
# 49  Question 1. I have the tools, technology and e...      38      44       4
# 92  Question 1. I have the tools, technology and e...      37      45       4
# 98  Question 1. I have the tools, technology and e...      38      46       4
#
#    ANSWER4 ANSWER5 ANSWER6 ANSWER7 MOST_POSITIVE_OR_LEAST_NEGATIVE  \
# 0        9       4       0       0                              84
# 6       10       4       0       0                              83
# 49      11       4       0       0                              82
# 92      10       3       0       0                              83
# 98      10       2       0       0                              85
#
#    NEUTRAL_OR_MIDDLE_CATEGORY MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5  \
# 0                           4                              12    84    4.1
# 6                           4                              13    83   4.04
# 49                          4                              14    82   4.02
# 92                          4                              13    83   4.04
# 98                          4                              12    85   4.09
#
#    SCORE100  ANSCOUNT                          DEPT_E  INDICATORID  \
# 0        78  189360.0                  Public Service            4
# 6        76    5575.0                   Health Canada            4
# 49       76    2215.0  Public Health Agency of Canada            4
# 92       76  188350.0                  Public Service            4
# 98       77    5240.0                   Health Canada            4
#
#    INDICATORENG  SUBINDICATORID                     SUBINDICATORENG
# 0     Workplace            14.0  Physical environment and equipment
# 6     Workplace            14.0  Physical environment and equipment
# 49    Workplace            14.0  Physical environment and equipment
# 92    Workplace            14.0  Physical environment and equipment
# 98    Workplace            14.0  Physical environment and equipment

# %%
df.shape
# Out:
# (1937, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1937 entries, 0 to 56048
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         1937 non-null   int64
#  1   LEVEL2ID                         1937 non-null   int64
#  2   LEVEL3ID                         1937 non-null   int64
#  3   LEVEL4ID                         1937 non-null   int64
#  4   LEVEL5ID                         1937 non-null   int64
#  5   SURVEYR                          1937 non-null   int64
#  6   BYCOND                           0 non-null      float64
#  7   descrip_E                        1937 non-null   object
#  8   DEMCODE                          0 non-null      float64
#  9   QUESTION                         1937 non-null   object
#  10  TITLE_E                          1937 non-null   object
#  11  ANSWER1                          1867 non-null   object
#  12  ANSWER2                          1867 non-null   object
#  13  ANSWER3                          1867 non-null   object
#  14  ANSWER4                          1867 non-null   object
#  15  ANSWER5                          1867 non-null   object
#  16  ANSWER6                          1867 non-null   object
#  17  ANSWER7                          1867 non-null   object
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  1867 non-null   object
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       1867 non-null   object
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  1867 non-null   object
#  21  AGREE                            1867 non-null   object
#  22  SCORE5                           1867 non-null   object
#  23  SCORE100                         1867 non-null   object
#  24  ANSCOUNT                         1867 non-null   float64
#  25  DEPT_E                           1937 non-null   object
#  26  INDICATORID                      1937 non-null   int64
#  27  INDICATORENG                     1937 non-null   object
#  28  SUBINDICATORID                   1937 non-null   float64
#  29  SUBINDICATORENG                  1937 non-null   object
# dtypes: float64(4), int64(7), object(19)
# memory usage: 469.1+ KB

# %%
# find the null values in the df
df.isnull().sum()
# Out:
# LEVEL1ID                              0
# LEVEL2ID                              0
# LEVEL3ID                              0
# LEVEL4ID                              0
# LEVEL5ID                              0
# SURVEYR                               0
# BYCOND                             1937
# descrip_E                             0
# DEMCODE                            1937
# QUESTION                              0
# TITLE_E                               0
# ANSWER1                              70
# ANSWER2                              70
# ANSWER3                              70
# ANSWER4                              70
# ANSWER5                              70
# ANSWER6                              70
# ANSWER7                              70
# MOST_POSITIVE_OR_LEAST_NEGATIVE      70
# NEUTRAL_OR_MIDDLE_CATEGORY           70
# MOST_NEGATIVE_OR_LEAST_POSITIVE      70
# AGREE                                70
# SCORE5                               70
# SCORE100                             70
# ANSCOUNT                             70
# DEPT_E                                0
# INDICATORID                           0
# INDICATORENG                          0
# SUBINDICATORID                        0
# SUBINDICATORENG                       0
# dtype: int64

# %%
# records where ANSWER1 = 'X'
df[df['ANSWER3'] == 'X']
# Out:
# Empty DataFrame
# Columns: [LEVEL1ID, LEVEL2ID, LEVEL3ID, LEVEL4ID, LEVEL5ID, SURVEYR, BYCOND, descrip_E, DEMCODE, QUESTION, TITLE_E, ANSWER1, ANSWER2, ANSWER3, ANSWER4, ANSWER5, ANSWER6, ANSWER7, MOST_POSITIVE_OR_LEAST_NEGATIVE, NEUTRAL_OR_MIDDLE_CATEGORY, MOST_NEGATIVE_OR_LEAST_POSITIVE, AGREE, SCORE5, SCORE100, ANSCOUNT, DEPT_E, INDICATORID, INDICATORENG, SUBINDICATORID, SUBINDICATORENG]
# Index: []

# %%
# records where ANSWER3 or ANSWER4 or ANSWER5 or ANSWER6 or ANSWER7 = '9999'
df[(df['ANSWER3'] == '9999') | (df['ANSWER4'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER7'] == '9999')]
# Out:
#        LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR  BYCOND  \
# 19069         0         0         0         0         0     2022     NaN
# 19075         6         0         0         0         0     2022     NaN
# 19118        70         0         0         0         0     2022     NaN
# 19161         0         0         0         0         0     2020     NaN
# 19167         6         0         0         0         0     2020     NaN
# ...         ...       ...       ...       ...       ...      ...     ...
# 52048         0         0         0         0         0     2019     NaN
# 52054         6         0         0         0         0     2019     NaN
# 52134         0         0         0         0         0     2018     NaN
# 52140         6         0         0         0         0     2018     NaN
# 52182        70         0         0         0         0     2018     NaN
#
#                             descrip_E  DEMCODE QUESTION  \
# 19069                  Public Service      NaN    D56_1
# 19075                   Health Canada      NaN    D56_1
# 19118  Public Health Agency of Canada      NaN    D56_1
# 19161                  Public Service      NaN    D56_1
# 19167                   Health Canada      NaN    D56_1
# ...                               ...      ...      ...
# 52048                  Public Service      NaN     Q68p
# 52054                   Health Canada      NaN     Q68p
# 52134                  Public Service      NaN     Q68p
# 52140                   Health Canada      NaN     Q68p
# 52182  Public Health Agency of Canada      NaN     Q68p
#
#                                                  TITLE_E ANSWER1 ANSWER2  \
# 19069  Question 56_1. Do you intend to leave your cur...      38      33
# 19075  Question 56_1. Do you intend to leave your cur...      37      30
# 19118  Question 56_1. Do you intend to leave your cur...      49      23
# 19161  Question 56_1. Do you intend to leave your cur...      24      41
# 19167  Question 56_1. Do you intend to leave your cur...      25      38
# ...                                                  ...     ...     ...
# 52048  Question 68p. Why did you not file a grievance...      11      89
# 52054  Question 68p. Why did you not file a grievance...      10      90
# 52134  Question 68p. Why did you not file a grievance...      13      87
# 52140  Question 68p. Why did you not file a grievance...      12      88
# 52182  Question 68p. Why did you not file a grievance...      15      85
#
#       ANSWER3 ANSWER4 ANSWER5 ANSWER6 ANSWER7 MOST_POSITIVE_OR_LEAST_NEGATIVE  \
# 19069      29    9999    9999    9999  9999.0                            9999
# 19075      33    9999    9999    9999  9999.0                            9999
# 19118      28    9999    9999    9999  9999.0                            9999
# 19161      35    9999    9999    9999  9999.0                            9999
# 19167      37    9999    9999    9999  9999.0                            9999
# ...       ...     ...     ...     ...     ...                             ...
# 52048    9999    9999    9999    9999    9999                            9999
# 52054    9999    9999    9999    9999    9999                            9999
# 52134    9999    9999    9999    9999    9999                            9999
# 52140    9999    9999    9999    9999    9999                            9999
# 52182    9999    9999    9999    9999    9999                            9999
#
#       NEUTRAL_OR_MIDDLE_CATEGORY MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5  \
# 19069                     9999.0                            9999    38   99.0
# 19075                     9999.0                            9999    37   99.0
# 19118                     9999.0                            9999    49   99.0
# 19161                     9999.0                            9999    24   99.0
# 19167                     9999.0                            9999    25   99.0
# ...                          ...                             ...   ...    ...
# 52048                       9999                            9999    11     99
# 52054                       9999                            9999    10     99
# 52134                       9999                            9999    13     99
# 52140                       9999                            9999    12     99
# 52182                       9999                            9999    15     99
#
#       SCORE100  ANSCOUNT                          DEPT_E  INDICATORID  \
# 19069   9999.0  189400.0                  Public Service            3
# 19075   9999.0    5570.0                   Health Canada            3
# 19118   9999.0    2220.0  Public Health Agency of Canada            3
# 19161   9999.0  188494.0                  Public Service            3
# 19167   9999.0    5238.0                   Health Canada            3
# ...        ...       ...                             ...          ...
# 52048     9999   11129.0                  Public Service            4
# 52054     9999     318.0                   Health Canada            4
# 52134     9999   11050.0                  Public Service            4
# 52140     9999     286.0                   Health Canada            4
# 52182     9999      80.0  Public Health Agency of Canada            4
#
#       INDICATORENG  SUBINDICATORID         SUBINDICATORENG
# 19069    Workforce             8.0  Mobility and retention
# 19075    Workforce             8.0  Mobility and retention
# 19118    Workforce             8.0  Mobility and retention
# 19161    Workforce             8.0  Mobility and retention
# 19167    Workforce             8.0  Mobility and retention
# ...            ...             ...                     ...
# 52048    Workplace            17.0          Discrimination
# 52054    Workplace            17.0          Discrimination
# 52134    Workplace            17.0          Discrimination
# 52140    Workplace            17.0          Discrimination
# 52182    Workplace            17.0          Discrimination
#
# [1040 rows x 30 columns]

# %%
# Replace and value in the dataset that equal to '9999' with NaN
df.replace([9999, '9999'], pd.NA, inplace=True)

# %%
# records where ANSWER3 or ANSWER4 or ANSWER5 or ANSWER6 or ANSWER7 = '9999'
df[(df['ANSWER3'] == '9999') | (df['ANSWER4'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER7'] == '9999')]
# Out:
# Empty DataFrame
# Columns: [LEVEL1ID, LEVEL2ID, LEVEL3ID, LEVEL4ID, LEVEL5ID, SURVEYR, BYCOND, descrip_E, DEMCODE, QUESTION, TITLE_E, ANSWER1, ANSWER2, ANSWER3, ANSWER4, ANSWER5, ANSWER6, ANSWER7, MOST_POSITIVE_OR_LEAST_NEGATIVE, NEUTRAL_OR_MIDDLE_CATEGORY, MOST_NEGATIVE_OR_LEAST_POSITIVE, AGREE, SCORE5, SCORE100, ANSCOUNT, DEPT_E, INDICATORID, INDICATORENG, SUBINDICATORID, SUBINDICATORENG]
# Index: []

# %%
# Replace and value in the dataset that equal to 'X' with NaN
df = df.replace('X', pd.NA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1937 entries, 0 to 56048
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         1937 non-null   int64
#  1   LEVEL2ID                         1937 non-null   int64
#  2   LEVEL3ID                         1937 non-null   int64
#  3   LEVEL4ID                         1937 non-null   int64
#  4   LEVEL5ID                         1937 non-null   int64
#  5   SURVEYR                          1937 non-null   int64
#  6   BYCOND                           0 non-null      float64
#  7   descrip_E                        1937 non-null   object
#  8   DEMCODE                          0 non-null      float64
#  9   QUESTION                         1937 non-null   object
#  10  TITLE_E                          1937 non-null   object
#  11  ANSWER1                          1867 non-null   object
#  12  ANSWER2                          1867 non-null   object
#  13  ANSWER3                          839 non-null    object
#  14  ANSWER4                          827 non-null    object
#  15  ANSWER5                          827 non-null    object
#  16  ANSWER6                          827 non-null    object
#  17  ANSWER7                          815 non-null    object
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  839 non-null    object
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       815 non-null    object
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  839 non-null    object
#  21  AGREE                            1855 non-null   object
#  22  SCORE5                           1867 non-null   object
#  23  SCORE100                         815 non-null    object
#  24  ANSCOUNT                         1867 non-null   float64
#  25  DEPT_E                           1937 non-null   object
#  26  INDICATORID                      1937 non-null   int64
#  27  INDICATORENG                     1937 non-null   object
#  28  SUBINDICATORID                   1937 non-null   float64
#  29  SUBINDICATORENG                  1937 non-null   object
# dtypes: float64(4), int64(7), object(19)
# memory usage: 469.1+ KB

# %%
# Change the data type of BYCOND to object
df['BYCOND'] = df['BYCOND'].astype(object)

# %%
# Change the data type of DEMCODE to int
df['DEMCODE'] = df['DEMCODE'].astype('Int64')

# %%
answers_cols = ['ANSWER1', 'ANSWER2', 'ANSWER3', 'ANSWER4', 'ANSWER5', 'ANSWER6', 'ANSWER7']

# %%
df[answers_cols] = df[answers_cols].apply(pd.to_numeric, errors='coerce')

# %%
# Change the data type of answers columns  to integer
df[answers_cols] = df[answers_cols].astype('Int64')

# %%
# Select the desired columns using a list
cols_to_convert = ['MOST_POSITIVE_OR_LEAST_NEGATIVE', 'NEUTRAL_OR_MIDDLE_CATEGORY', 'MOST_NEGATIVE_OR_LEAST_POSITIVE','AGREE','SCORE5','SCORE100','ANSCOUNT']
# Apply pd.to_numeric to the selected columns
df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
# Change the data type of columns ANSWER1 and ANSWER2 to integer
df[cols_to_convert] = df[cols_to_convert].astype(pd.Int64Dtype(),errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1937 entries, 0 to 56048
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         1937 non-null   int64
#  1   LEVEL2ID                         1937 non-null   int64
#  2   LEVEL3ID                         1937 non-null   int64
#  3   LEVEL4ID                         1937 non-null   int64
#  4   LEVEL5ID                         1937 non-null   int64
#  5   SURVEYR                          1937 non-null   int64
#  6   BYCOND                           0 non-null      object
#  7   descrip_E                        1937 non-null   object
#  8   DEMCODE                          0 non-null      Int64
#  9   QUESTION                         1937 non-null   object
#  10  TITLE_E                          1937 non-null   object
#  11  ANSWER1                          1867 non-null   Int64
#  12  ANSWER2                          1867 non-null   Int64
#  13  ANSWER3                          839 non-null    Int64
#  14  ANSWER4                          827 non-null    Int64
#  15  ANSWER5                          827 non-null    Int64
#  16  ANSWER6                          827 non-null    Int64
#  17  ANSWER7                          815 non-null    Int64
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  839 non-null    Int64
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       815 non-null    Int64
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  839 non-null    Int64
#  21  AGREE                            1855 non-null   Int64
#  22  SCORE5                           1867 non-null   float64
#  23  SCORE100                         815 non-null    Int64
#  24  ANSCOUNT                         1867 non-null   Int64
#  25  DEPT_E                           1937 non-null   object
#  26  INDICATORID                      1937 non-null   int64
#  27  INDICATORENG                     1937 non-null   object
#  28  SUBINDICATORID                   1937 non-null   float64
#  29  SUBINDICATORENG                  1937 non-null   object
# dtypes: Int64(14), float64(2), int64(7), object(7)
# memory usage: 495.6+ KB

# %%
# Create new column call it SUM_ANSRS, fill it with the sum of columns ANSWER1 and ANSWER2 and ANSWER3 andANSWER4 and ANSWER5 and ANSWER6 and ANSWER7
#df['SUM_ANSRS'] = df['ANSWER1'] + df['ANSWER2'] + df['ANSWER3']+ df['ANSWER4']+ df['ANSWER4']+ df['ANSWER6']+ df['ANSWER7']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1937 entries, 0 to 56048
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         1937 non-null   int64
#  1   LEVEL2ID                         1937 non-null   int64
#  2   LEVEL3ID                         1937 non-null   int64
#  3   LEVEL4ID                         1937 non-null   int64
#  4   LEVEL5ID                         1937 non-null   int64
#  5   SURVEYR                          1937 non-null   int64
#  6   BYCOND                           0 non-null      object
#  7   descrip_E                        1937 non-null   object
#  8   DEMCODE                          0 non-null      Int64
#  9   QUESTION                         1937 non-null   object
#  10  TITLE_E                          1937 non-null   object
#  11  ANSWER1                          1867 non-null   Int64
#  12  ANSWER2                          1867 non-null   Int64
#  13  ANSWER3                          839 non-null    Int64
#  14  ANSWER4                          827 non-null    Int64
#  15  ANSWER5                          827 non-null    Int64
#  16  ANSWER6                          827 non-null    Int64
#  17  ANSWER7                          815 non-null    Int64
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  839 non-null    Int64
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       815 non-null    Int64
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  839 non-null    Int64
#  21  AGREE                            1855 non-null   Int64
#  22  SCORE5                           1867 non-null   float64
#  23  SCORE100                         815 non-null    Int64
#  24  ANSCOUNT                         1867 non-null   Int64
#  25  DEPT_E                           1937 non-null   object
#  26  INDICATORID                      1937 non-null   int64
#  27  INDICATORENG                     1937 non-null   object
#  28  SUBINDICATORID                   1937 non-null   float64
#  29  SUBINDICATORENG                  1937 non-null   object
# dtypes: Int64(14), float64(2), int64(7), object(7)
# memory usage: 495.6+ KB

# %%
df.head()
# Out:
#     LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR BYCOND  \
# 0          0         0         0         0         0     2022    NaN
# 6          6         0         0         0         0     2022    NaN
# 49        70         0         0         0         0     2022    NaN
# 92         0         0         0         0         0     2020    NaN
# 98         6         0         0         0         0     2020    NaN
#
#                          descrip_E  DEMCODE QUESTION  \
# 0                   Public Service     <NA>      Q01
# 6                    Health Canada     <NA>      Q01
# 49  Public Health Agency of Canada     <NA>      Q01
# 92                  Public Service     <NA>      Q01
# 98                   Health Canada     <NA>      Q01
#
#                                               TITLE_E  ANSWER1  ANSWER2  \
# 0   Question 1. I have the tools, technology and e...       43       41
# 6   Question 1. I have the tools, technology and e...       39       44
# 49  Question 1. I have the tools, technology and e...       38       44
# 92  Question 1. I have the tools, technology and e...       37       45
# 98  Question 1. I have the tools, technology and e...       38       46
#
#     ANSWER3  ANSWER4  ANSWER5  ANSWER6  ANSWER7  \
# 0         4        9        4        0        0
# 6         4       10        4        0        0
# 49        4       11        4        0        0
# 92        4       10        3        0        0
# 98        4       10        2        0        0
#
#     MOST_POSITIVE_OR_LEAST_NEGATIVE  NEUTRAL_OR_MIDDLE_CATEGORY  \
# 0                                84                           4
# 6                                83                           4
# 49                               82                           4
# 92                               83                           4
# 98                               85                           4
#
#     MOST_NEGATIVE_OR_LEAST_POSITIVE  AGREE  SCORE5  SCORE100  ANSCOUNT  \
# 0                                12     84    4.10        78    189360
# 6                                13     83    4.04        76      5575
# 49                               14     82    4.02        76      2215
# 92                               13     83    4.04        76    188350
# 98                               12     85    4.09        77      5240
#
#                             DEPT_E  INDICATORID INDICATORENG  SUBINDICATORID  \
# 0                   Public Service            4    Workplace            14.0
# 6                    Health Canada            4    Workplace            14.0
# 49  Public Health Agency of Canada            4    Workplace            14.0
# 92                  Public Service            4    Workplace            14.0
# 98                   Health Canada            4    Workplace            14.0
#
#                        SUBINDICATORENG
# 0   Physical environment and equipment
# 6   Physical environment and equipment
# 49  Physical environment and equipment
# 92  Physical environment and equipment
# 98  Physical environment and equipment

# %%
answer_cols = ["ANSWER1", "ANSWER2", "ANSWER3", "ANSWER4", "ANSWER5", "ANSWER6"]
df[answer_cols] = df[answer_cols].apply(pd.to_numeric, errors='coerce')

# %%
# CASE 1: If ANSWER3 is null
df.loc[df['ANSWER3'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1']
df.loc[df['ANSWER3'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER2']

# CASE 2: If ANSWER3 is not null and ANSWER4 is null
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].isna(), 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER2']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER3']

# CASE 3: If ANSWER3 is not null, ANSWER4 is not null, and ANSWER5 is null
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1'] + df['ANSWER2']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].isna(), 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER3']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER4']

# CASE 4: If ANSWER3, ANSWER4, ANSWER5 are not null, and ANSWER6 is null
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].notna() & df['ANSWER6'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1'] + df['ANSWER2']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].notna() & df['ANSWER6'].isna(), 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER3']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].notna() & df['ANSWER6'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER4']

# %%
df.isnull().sum()
# Out:
# LEVEL1ID                              0
# LEVEL2ID                              0
# LEVEL3ID                              0
# LEVEL4ID                              0
# LEVEL5ID                              0
# SURVEYR                               0
# BYCOND                             1937
# descrip_E                             0
# DEMCODE                            1937
# QUESTION                              0
# TITLE_E                               0
# ANSWER1                              70
# ANSWER2                              70
# ANSWER3                            1098
# ANSWER4                            1110
# ANSWER5                            1110
# ANSWER6                            1110
# ANSWER7                            1122
# MOST_POSITIVE_OR_LEAST_NEGATIVE      82
# NEUTRAL_OR_MIDDLE_CATEGORY         1110
# MOST_NEGATIVE_OR_LEAST_POSITIVE      82
# AGREE                                82
# SCORE5                               70
# SCORE100                           1122
# ANSCOUNT                             70
# DEPT_E                                0
# INDICATORID                           0
# INDICATORENG                          0
# SUBINDICATORID                        0
# SUBINDICATORENG                       0
# dtype: int64

# %%
# export the dataset df_HC to a csv file and call it subset1_HealthCanada
df.to_csv('subset1_cleaned.csv', index=False)

# %%
# in 'QUESTION' where the Values = D56_1 change it to Q56_1
df.loc[df['QUESTION'] == 'D56_1', 'QUESTION'] = 'Q56_1'

# %%
# in 'QUESTION' where the Values = D56_2 change it to Q56_2
df.loc[df['QUESTION'] == 'D56_2', 'QUESTION'] = 'Q56_2'

# %%
# Define the columns to be set to NaN
cols_to_nullify = [
    "MOST_POSITIVE_OR_LEAST_NEGATIVE",
    "NEUTRAL_OR_MIDDLE_CATEGORY",
    "MOST_NEGATIVE_OR_LEAST_POSITIVE",
    "AGREE",
    "SCORE5",
    "SCORE100"
]

# Set the columns to NaN where QUESTIONS that doesnt have sentiment asnwers
df.loc[df['QUESTION'].isin(['Q56_1', 'Q56_2', 'Q81', 'Q83', 'Q93', 'Q95']), cols_to_nullify] = pd.NA

# %%
# Set the values where QUESTION is 'Q88'
df.loc[df['QUESTION'] == 'Q88', 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER2']
df.loc[df['QUESTION'] == 'Q88', 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER1']
df.loc[df['QUESTION'] == 'Q88', 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER3'] + df['ANSWER4']

# %%
import re

# Define the pattern to match questions like Q57, Q58, Q59, etc., including any suffix (e.g., Q58a, Q58b, etc.)
questions_pattern = r'Q(57|58|59|60|61|64|65|67|68)[a-zA-Z]?'

# Set the values where QUESTION matches the pattern
df.loc[df['QUESTION'].str.match(questions_pattern), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER2']
df.loc[df['QUESTION'].str.match(questions_pattern), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER1']

# %%
# export the dataset df_HC to a csv file and call it subset1_HealthCanada
df.to_csv('subset1_cleaned.csv', index=False)
