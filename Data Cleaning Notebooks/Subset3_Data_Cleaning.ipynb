# %%
import pandas as pd

# %%
# Import the data
data = pd.read_csv('Subset 3 - 2022_2023 PSES open dataset - with labels_Sous-ensemble 3 - Ensemble de données ouvertes du SAFF de 2022_23.csv', encoding='latin-1')

# %%
data.shape
# Out:
# (471994, 35)

# %%
# show head of the data, and show all the columns
pd.set_option('display.max_columns', None)
data.head()
# Out:
#    LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR    BYCOND  \
# 0         0         0         0         0         0     2022  Q117 = 1
# 1         1         0         0         0         0     2022  Q117 = 1
# 2         2         0         0         0         0     2022  Q117 = 1
# 3         3         0         0         0         0     2022  Q117 = 1
# 4         4         0         0         0         0     2022  Q117 = 1
#
#   descrip_E descrip_F  DEMCODE QUESTION  \
# 0       Man     Homme     1087      Q01
# 1       Man     Homme     1087      Q01
# 2       Man     Homme     1087      Q01
# 3       Man     Homme     1087      Q01
# 4       Man     Homme     1087      Q01
#
#                                              TITLE_E  \
# 0  Question 1. I have the tools, technology and e...
# 1  Question 1. I have the tools, technology and e...
# 2  Question 1. I have the tools, technology and e...
# 3  Question 1. I have the tools, technology and e...
# 4  Question 1. I have the tools, technology and e...
#
#                                              TITLE_F ANSWER1 ANSWER2 ANSWER3  \
# 0  Question 1. Je dispose des outils, de la techn...      39      42       5
# 1  Question 1. Je dispose des outils, de la techn...      53      37       3
# 2  Question 1. Je dispose des outils, de la techn...      51      37       3
# 3  Question 1. Je dispose des outils, de la techn...      28      45       6
# 4  Question 1. Je dispose des outils, de la techn...      17      45       7
#
#   ANSWER4 ANSWER5 ANSWER6 ANSWER7 MOST_POSITIVE_OR_LEAST_NEGATIVE  \
# 0       9       5       0       0                              81
# 1       5       2       0       0                              91
# 2       6       3       0       0                              88
# 3      13       7       0       0                              73
# 4      17      13       0       0                              63
#
#   NEUTRAL_OR_MIDDLE_CATEGORY MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5  \
# 0                          5                              14    81   4.02
# 1                          3                               6    91   4.36
# 2                          3                               9    88   4.27
# 3                          6                              21    73   3.73
# 4                          7                              30    63   3.36
#
#   SCORE100  ANSCOUNT                                    DEPT_E  \
# 0       76   69605.0                            Public Service
# 1       84   13060.0                     Canada Revenue Agency
# 2       82    6090.0  Employment and Social Development Canada
# 3       68    6330.0            Department of National Defence
# 4       59    2310.0               Correctional Service Canada
#
#                                   DEPT_F  INDICATORID INDICATORENG  \
# 0                      Fonction publique          4.0    Workplace
# 1             Agence du revenu du Canada          4.0    Workplace
# 2  Emploi et Développement social Canada          4.0    Workplace
# 3      Ministère de la Défense nationale          4.0    Workplace
# 4           Service correctionnel Canada          4.0    Workplace
#
#         INDICATORFRA  SUBINDICATORID                     SUBINDICATORENG  \
# 0  Milieu de travail            14.0  Physical environment and equipment
# 1  Milieu de travail            14.0  Physical environment and equipment
# 2  Milieu de travail            14.0  Physical environment and equipment
# 3  Milieu de travail            14.0  Physical environment and equipment
# 4  Milieu de travail            14.0  Physical environment and equipment
#
#                         SUBINDICATORFRA
# 0  Environnement physique et équipement
# 1  Environnement physique et équipement
# 2  Environnement physique et équipement
# 3  Environnement physique et équipement
# 4  Environnement physique et équipement

# %%
data.tail()
# Out:
#         LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR     BYCOND  \
# 471989        31         0         0         0         0     2022  D122G = 1
# 471990        35         0         0         0         0     2022  D122G = 1
# 471991        36         0         0         0         0     2022  D122G = 1
# 471992        37         0         0         0         0     2022  D122G = 1
# 471993        39         0         0         0         0     2022  D122G = 1
#
#                       descrip_E                       descrip_F  DEMCODE  \
# 471989  2SLGBTQIA+: Questioning  2ELGBTQIA+ : En questionnement     1158
# 471990  2SLGBTQIA+: Questioning  2ELGBTQIA+ : En questionnement     1158
# 471991  2SLGBTQIA+: Questioning  2ELGBTQIA+ : En questionnement     1158
# 471992  2SLGBTQIA+: Questioning  2ELGBTQIA+ : En questionnement     1158
# 471993  2SLGBTQIA+: Questioning  2ELGBTQIA+ : En questionnement     1158
#
#        QUESTION                                            TITLE_E  \
# 471989      Q55  Question 55. I would prefer to remain with my ...
# 471990      Q55  Question 55. I would prefer to remain with my ...
# 471991      Q55  Question 55. I would prefer to remain with my ...
# 471992      Q55  Question 55. I would prefer to remain with my ...
# 471993      Q55  Question 55. I would prefer to remain with my ...
#
#                                                   TITLE_F ANSWER1 ANSWER2  \
# 471989  Question 55. Je préférerais continuer à travai...       X       X
# 471990  Question 55. Je préférerais continuer à travai...       X       X
# 471991  Question 55. Je préférerais continuer à travai...       X       X
# 471992  Question 55. Je préférerais continuer à travai...       X       X
# 471993  Question 55. Je préférerais continuer à travai...       X       X
#
#        ANSWER3 ANSWER4 ANSWER5 ANSWER6 ANSWER7  \
# 471989       X       X       X       X       X
# 471990       X       X       X       X       X
# 471991       X       X       X       X       X
# 471992       X       X       X       X       X
# 471993       X       X       X       X       X
#
#        MOST_POSITIVE_OR_LEAST_NEGATIVE NEUTRAL_OR_MIDDLE_CATEGORY  \
# 471989                               X                          X
# 471990                               X                          X
# 471991                               X                          X
# 471992                               X                          X
# 471993                               X                          X
#
#        MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5 SCORE100  ANSCOUNT  \
# 471989                               X     X      X        X       NaN
# 471990                               X     X      X        X       NaN
# 471991                               X     X      X        X       NaN
# 471992                               X     X      X        X       NaN
# 471993                               X     X      X        X       NaN
#
#                                                    DEPT_E  \
# 471989  Canadian Radio-television and Telecommunicatio...
# 471990             Canadian Institutes of Health Research
# 471991                             Parole Board of Canada
# 471992                             Shared Services Canada
# 471993                                     Transportation
#
#                                                    DEPT_F  INDICATORID  \
# 471989  Conseil de la radiodiffusion et des télécommun...          1.0
# 471990          Instituts de recherche en santé du Canada          1.0
# 471991  Commission des libérations conditionnelles du ...          1.0
# 471992                           Services partagés Canada          1.0
# 471993                                                NaN          NaN
#
#                INDICATORENG               INDICATORFRA  SUBINDICATORID  \
# 471989  Employee engagement  Mobilisation des employés             1.0
# 471990  Employee engagement  Mobilisation des employés             1.0
# 471991  Employee engagement  Mobilisation des employés             1.0
# 471992  Employee engagement  Mobilisation des employés             1.0
# 471993                  NaN                        NaN             NaN
#
#             SUBINDICATORENG            SUBINDICATORFRA
# 471989  Employee engagement  Mobilisation des employés
# 471990  Employee engagement  Mobilisation des employés
# 471991  Employee engagement  Mobilisation des employés
# 471992  Employee engagement  Mobilisation des employés
# 471993                  NaN                        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471994 entries, 0 to 471993
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   LEVEL1ID                         471994 non-null  int64
#  1   LEVEL2ID                         471994 non-null  int64
#  2   LEVEL3ID                         471994 non-null  int64
#  3   LEVEL4ID                         471994 non-null  int64
#  4   LEVEL5ID                         471994 non-null  int64
#  5   SURVEYR                          471994 non-null  int64
#  6   BYCOND                           471994 non-null  object
#  7   descrip_E                        471994 non-null  object
#  8   descrip_F                        471994 non-null  object
#  9   DEMCODE                          471994 non-null  int64
#  10  QUESTION                         471994 non-null  object
#  11  TITLE_E                          471994 non-null  object
#  12  TITLE_F                          471994 non-null  object
#  13  ANSWER1                          417655 non-null  object
#  14  ANSWER2                          417655 non-null  object
#  15  ANSWER3                          417655 non-null  object
#  16  ANSWER4                          417655 non-null  object
#  17  ANSWER5                          417655 non-null  object
#  18  ANSWER6                          417655 non-null  object
#  19  ANSWER7                          417655 non-null  object
#  20  MOST_POSITIVE_OR_LEAST_NEGATIVE  417655 non-null  object
#  21  NEUTRAL_OR_MIDDLE_CATEGORY       417655 non-null  object
#  22  MOST_NEGATIVE_OR_LEAST_POSITIVE  417655 non-null  object
#  23  AGREE                            417655 non-null  object
#  24  SCORE5                           417655 non-null  object
#  25  SCORE100                         417655 non-null  object
#  26  ANSCOUNT                         306624 non-null  float64
#  27  DEPT_E                           471994 non-null  object
#  28  DEPT_F                           471993 non-null  object
#  29  INDICATORID                      471993 non-null  float64
#  30  INDICATORENG                     471993 non-null  object
#  31  INDICATORFRA                     471993 non-null  object
#  32  SUBINDICATORID                   471993 non-null  float64
#  33  SUBINDICATORENG                  471993 non-null  object
#  34  SUBINDICATORFRA                  471993 non-null  object
# dtypes: float64(3), int64(7), object(25)
# memory usage: 126.0+ MB

# %%
# dropping the french columns: descrip_F,TITLE_F ,DEPT_F ,SUBINDICATORFRA,INDICATORFRA AND SAVE IT IN A NEW datafarme call ot df_HC
df = data.drop(columns=['descrip_F', 'TITLE_F', 'DEPT_F', 'SUBINDICATORFRA', 'INDICATORFRA'])

# %%
# extract the df to be equal only where DEPT_E = 'Health Canada'or 'Public Service' or'Public Health Agency of Canada'
df = df[df['DEPT_E'].isin(['Health Canada', 'Public Service', 'Public Health Agency of Canada'])]
df.head()
# Out:
#     LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR    BYCOND  \
# 0          0         0         0         0         0     2022  Q117 = 1
# 6          6         0         0         0         0     2022  Q117 = 1
# 49        70         0         0         0         0     2022  Q117 = 1
# 69         0         0         0         0         0     2020  Q117 = 1
# 75         6         0         0         0         0     2020  Q117 = 1
#
#    descrip_E  DEMCODE QUESTION  \
# 0        Man     1087      Q01
# 6        Man     1087      Q01
# 49       Man     1087      Q01
# 69       Man     1087      Q01
# 75       Man     1087      Q01
#
#                                               TITLE_E ANSWER1 ANSWER2 ANSWER3  \
# 0   Question 1. I have the tools, technology and e...      39      42       5
# 6   Question 1. I have the tools, technology and e...      37      46       4
# 49  Question 1. I have the tools, technology and e...      40      41       5
# 69  Question 1. I have the tools, technology and e...      35      45       6
# 75  Question 1. I have the tools, technology and e...      37      46       6
#
#    ANSWER4 ANSWER5 ANSWER6 ANSWER7 MOST_POSITIVE_OR_LEAST_NEGATIVE  \
# 0        9       5       0       0                              81
# 6       10       3       0       0                              83
# 49      10       4       0       0                              81
# 69      11       3       0       0                              81
# 75       9       2       0       0                              83
#
#    NEUTRAL_OR_MIDDLE_CATEGORY MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5  \
# 0                           5                              14    81   4.02
# 6                           4                              13    83   4.03
# 49                          5                              14    81   4.04
# 69                          6                              14    81   3.99
# 75                          6                              11    83   4.07
#
#    SCORE100  ANSCOUNT                          DEPT_E  INDICATORID  \
# 0        76   69605.0                  Public Service          4.0
# 6        76    1715.0                   Health Canada          4.0
# 49       76     530.0  Public Health Agency of Canada          4.0
# 69       75   73497.0                  Public Service          4.0
# 75       77    1613.0                   Health Canada          4.0
#
#    INDICATORENG  SUBINDICATORID                     SUBINDICATORENG
# 0     Workplace            14.0  Physical environment and equipment
# 6     Workplace            14.0  Physical environment and equipment
# 49    Workplace            14.0  Physical environment and equipment
# 69    Workplace            14.0  Physical environment and equipment
# 75    Workplace            14.0  Physical environment and equipment

# %%
df.shape
# Out:
# (22198, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22198 entries, 0 to 471967
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         22198 non-null  int64
#  1   LEVEL2ID                         22198 non-null  int64
#  2   LEVEL3ID                         22198 non-null  int64
#  3   LEVEL4ID                         22198 non-null  int64
#  4   LEVEL5ID                         22198 non-null  int64
#  5   SURVEYR                          22198 non-null  int64
#  6   BYCOND                           22198 non-null  object
#  7   descrip_E                        22198 non-null  object
#  8   DEMCODE                          22198 non-null  int64
#  9   QUESTION                         22198 non-null  object
#  10  TITLE_E                          22198 non-null  object
#  11  ANSWER1                          21305 non-null  object
#  12  ANSWER2                          21305 non-null  object
#  13  ANSWER3                          21305 non-null  object
#  14  ANSWER4                          21305 non-null  object
#  15  ANSWER5                          21305 non-null  object
#  16  ANSWER6                          21305 non-null  object
#  17  ANSWER7                          21305 non-null  object
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  21305 non-null  object
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       21305 non-null  object
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  21305 non-null  object
#  21  AGREE                            21305 non-null  object
#  22  SCORE5                           21305 non-null  object
#  23  SCORE100                         21305 non-null  object
#  24  ANSCOUNT                         19836 non-null  float64
#  25  DEPT_E                           22198 non-null  object
#  26  INDICATORID                      22198 non-null  float64
#  27  INDICATORENG                     22198 non-null  object
#  28  SUBINDICATORID                   22198 non-null  float64
#  29  SUBINDICATORENG                  22198 non-null  object
# dtypes: float64(3), int64(7), object(20)
# memory usage: 5.3+ MB

# %%
# find the null values in the df
df.isnull().sum()
# Out:
# LEVEL1ID                              0
# LEVEL2ID                              0
# LEVEL3ID                              0
# LEVEL4ID                              0
# LEVEL5ID                              0
# SURVEYR                               0
# BYCOND                                0
# descrip_E                             0
# DEMCODE                               0
# QUESTION                              0
# TITLE_E                               0
# ANSWER1                             893
# ANSWER2                             893
# ANSWER3                             893
# ANSWER4                             893
# ANSWER5                             893
# ANSWER6                             893
# ANSWER7                             893
# MOST_POSITIVE_OR_LEAST_NEGATIVE     893
# NEUTRAL_OR_MIDDLE_CATEGORY          893
# MOST_NEGATIVE_OR_LEAST_POSITIVE     893
# AGREE                               893
# SCORE5                              893
# SCORE100                            893
# ANSCOUNT                           2362
# DEPT_E                                0
# INDICATORID                           0
# INDICATORENG                          0
# SUBINDICATORID                        0
# SUBINDICATORENG                       0
# dtype: int64

# %%
# records where ANSWER1 = 'X'
df[df['ANSWER3'] == 'X']
# Out:
#         LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR     BYCOND  \
# 310           70         0         0         0         0     2022   Q117 = 3
# 1045           6         0         0         0         0     2022  D118C = 1
# 1078          70         0         0         0         0     2022  D118C = 1
# 1097           6         0         0         0         0     2022  D118C = 2
# 1140          70         0         0         0         0     2022  D118C = 2
# ...          ...       ...       ...       ...       ...      ...        ...
# 471315         6         0         0         0         0     2022  D121 = 20
# 471370        70         0         0         0         0     2022  D121 = 21
# 471594         6         0         0         0         0     2022  D122A = 1
# 471621        70         0         0         0         0     2022  D122A = 1
# 471879        70         0         0         0         0     2022  D122E = 1
#
#                                                 descrip_E  DEMCODE QUESTION  \
# 310                                        Another gender     1089      Q01
# 1045         Persons with a disability, speech disability     1095      Q01
# 1078         Persons with a disability, speech disability     1095      Q01
# 1097    Persons with a disability, speech disability n...     1096      Q01
# 1140    Persons with a disability, speech disability n...     1096      Q01
# ...                                                   ...      ...      ...
# 471315            Two or more Ethnic Origins, Africa only     1147      Q55
# 471370              Two or more Ethnic Origins, Asia only     1148      Q55
# 471594                             2SLGBTQIA+: Two-spirit     1152      Q55
# 471621                             2SLGBTQIA+: Two-spirit     1152      Q55
# 471879                            2SLGBTQIA+: Transgender     1156      Q55
#
#                                                   TITLE_E ANSWER1 ANSWER2  \
# 310     Question 1. I have the tools, technology and e...       X       X
# 1045    Question 1. I have the tools, technology and e...       X       X
# 1078    Question 1. I have the tools, technology and e...       X       X
# 1097    Question 1. I have the tools, technology and e...       X       X
# 1140    Question 1. I have the tools, technology and e...       X       X
# ...                                                   ...     ...     ...
# 471315  Question 55. I would prefer to remain with my ...       X       X
# 471370  Question 55. I would prefer to remain with my ...       X       X
# 471594  Question 55. I would prefer to remain with my ...       X       X
# 471621  Question 55. I would prefer to remain with my ...       X       X
# 471879  Question 55. I would prefer to remain with my ...       X       X
#
#        ANSWER3 ANSWER4 ANSWER5 ANSWER6 ANSWER7  \
# 310          X       X       X       X       X
# 1045         X       X       X       X       X
# 1078         X       X       X       X       X
# 1097         X       X       X       X       X
# 1140         X       X       X       X       X
# ...        ...     ...     ...     ...     ...
# 471315       X       X       X       X       X
# 471370       X       X       X       X       X
# 471594       X       X       X       X       X
# 471621       X       X       X       X       X
# 471879       X       X       X       X       X
#
#        MOST_POSITIVE_OR_LEAST_NEGATIVE NEUTRAL_OR_MIDDLE_CATEGORY  \
# 310                                  X                          X
# 1045                                 X                          X
# 1078                                 X                          X
# 1097                                 X                          X
# 1140                                 X                          X
# ...                                ...                        ...
# 471315                               X                          X
# 471370                               X                          X
# 471594                               X                          X
# 471621                               X                          X
# 471879                               X                          X
#
#        MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5 SCORE100  ANSCOUNT  \
# 310                                  X     X      X        X       NaN
# 1045                                 X     X      X        X       NaN
# 1078                                 X     X      X        X       NaN
# 1097                                 X     X      X        X       NaN
# 1140                                 X     X      X        X       NaN
# ...                                ...   ...    ...      ...       ...
# 471315                               X     X      X        X       NaN
# 471370                               X     X      X        X       NaN
# 471594                               X     X      X        X       NaN
# 471621                               X     X      X        X       NaN
# 471879                               X     X      X        X       NaN
#
#                                 DEPT_E  INDICATORID         INDICATORENG  \
# 310     Public Health Agency of Canada          4.0            Workplace
# 1045                     Health Canada          4.0            Workplace
# 1078    Public Health Agency of Canada          4.0            Workplace
# 1097                     Health Canada          4.0            Workplace
# 1140    Public Health Agency of Canada          4.0            Workplace
# ...                                ...          ...                  ...
# 471315                   Health Canada          1.0  Employee engagement
# 471370  Public Health Agency of Canada          1.0  Employee engagement
# 471594                   Health Canada          1.0  Employee engagement
# 471621  Public Health Agency of Canada          1.0  Employee engagement
# 471879  Public Health Agency of Canada          1.0  Employee engagement
#
#         SUBINDICATORID                     SUBINDICATORENG
# 310               14.0  Physical environment and equipment
# 1045              14.0  Physical environment and equipment
# 1078              14.0  Physical environment and equipment
# 1097              14.0  Physical environment and equipment
# 1140              14.0  Physical environment and equipment
# ...                ...                                 ...
# 471315             1.0                 Employee engagement
# 471370             1.0                 Employee engagement
# 471594             1.0                 Employee engagement
# 471621             1.0                 Employee engagement
# 471879             1.0                 Employee engagement
#
# [1469 rows x 30 columns]

# %%
# records where ANSWER3 or ANSWER4 or ANSWER5 or ANSWER6 or ANSWER7 = '9999'
df[(df['ANSWER3'] == '9999') | (df['ANSWER4'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER7'] == '9999')]
# Out:
# Empty DataFrame
# Columns: [LEVEL1ID, LEVEL2ID, LEVEL3ID, LEVEL4ID, LEVEL5ID, SURVEYR, BYCOND, descrip_E, DEMCODE, QUESTION, TITLE_E, ANSWER1, ANSWER2, ANSWER3, ANSWER4, ANSWER5, ANSWER6, ANSWER7, MOST_POSITIVE_OR_LEAST_NEGATIVE, NEUTRAL_OR_MIDDLE_CATEGORY, MOST_NEGATIVE_OR_LEAST_POSITIVE, AGREE, SCORE5, SCORE100, ANSCOUNT, DEPT_E, INDICATORID, INDICATORENG, SUBINDICATORID, SUBINDICATORENG]
# Index: []

# %%
# Replace and value in the dataset that equal to '9999' with NaN
df.replace([9999, '9999'], pd.NA, inplace=True)

# %%
# records where ANSWER3 or ANSWER4 or ANSWER5 or ANSWER6 or ANSWER7 = '9999'
df[(df['ANSWER3'] == '9999') | (df['ANSWER4'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER7'] == '9999')]
# Out:
# Empty DataFrame
# Columns: [LEVEL1ID, LEVEL2ID, LEVEL3ID, LEVEL4ID, LEVEL5ID, SURVEYR, BYCOND, descrip_E, DEMCODE, QUESTION, TITLE_E, ANSWER1, ANSWER2, ANSWER3, ANSWER4, ANSWER5, ANSWER6, ANSWER7, MOST_POSITIVE_OR_LEAST_NEGATIVE, NEUTRAL_OR_MIDDLE_CATEGORY, MOST_NEGATIVE_OR_LEAST_POSITIVE, AGREE, SCORE5, SCORE100, ANSCOUNT, DEPT_E, INDICATORID, INDICATORENG, SUBINDICATORID, SUBINDICATORENG]
# Index: []

# %%
# Replace and value in the dataset that equal to 'X' with NaN
df = df.replace('X', pd.NA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22198 entries, 0 to 471967
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         22198 non-null  int64
#  1   LEVEL2ID                         22198 non-null  int64
#  2   LEVEL3ID                         22198 non-null  int64
#  3   LEVEL4ID                         22198 non-null  int64
#  4   LEVEL5ID                         22198 non-null  int64
#  5   SURVEYR                          22198 non-null  int64
#  6   BYCOND                           22198 non-null  object
#  7   descrip_E                        22198 non-null  object
#  8   DEMCODE                          22198 non-null  int64
#  9   QUESTION                         22198 non-null  object
#  10  TITLE_E                          22198 non-null  object
#  11  ANSWER1                          19836 non-null  object
#  12  ANSWER2                          19836 non-null  object
#  13  ANSWER3                          19836 non-null  object
#  14  ANSWER4                          19836 non-null  object
#  15  ANSWER5                          19836 non-null  object
#  16  ANSWER6                          19836 non-null  object
#  17  ANSWER7                          19836 non-null  object
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  19836 non-null  object
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       19836 non-null  object
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  19836 non-null  object
#  21  AGREE                            19836 non-null  object
#  22  SCORE5                           19836 non-null  object
#  23  SCORE100                         19836 non-null  object
#  24  ANSCOUNT                         19836 non-null  float64
#  25  DEPT_E                           22198 non-null  object
#  26  INDICATORID                      22198 non-null  float64
#  27  INDICATORENG                     22198 non-null  object
#  28  SUBINDICATORID                   22198 non-null  float64
#  29  SUBINDICATORENG                  22198 non-null  object
# dtypes: float64(3), int64(7), object(20)
# memory usage: 5.3+ MB

# %%
# Change the data type of BYCOND to object
df['BYCOND'] = df['BYCOND'].astype(object)

# %%
# Change the data type of DEMCODE to int
df['DEMCODE'] = df['DEMCODE'].astype('Int64')

# %%
answers_cols = ['ANSWER1', 'ANSWER2', 'ANSWER3', 'ANSWER4', 'ANSWER5', 'ANSWER6', 'ANSWER7']

# %%
df[answers_cols] = df[answers_cols].apply(pd.to_numeric, errors='coerce')

# %%
# Change the data type of answers columns  to integer
df[answers_cols] = df[answers_cols].astype('Int64')

# %%
# Select the desired columns using a list
cols_to_convert = ['MOST_POSITIVE_OR_LEAST_NEGATIVE', 'NEUTRAL_OR_MIDDLE_CATEGORY', 'MOST_NEGATIVE_OR_LEAST_POSITIVE','AGREE','SCORE5','SCORE100','ANSCOUNT']
# Apply pd.to_numeric to the selected columns
df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
# Change the data type of columns ANSWER1 and ANSWER2 to integer
df[cols_to_convert] = df[cols_to_convert].astype(pd.Int64Dtype(),errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22198 entries, 0 to 471967
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         22198 non-null  int64
#  1   LEVEL2ID                         22198 non-null  int64
#  2   LEVEL3ID                         22198 non-null  int64
#  3   LEVEL4ID                         22198 non-null  int64
#  4   LEVEL5ID                         22198 non-null  int64
#  5   SURVEYR                          22198 non-null  int64
#  6   BYCOND                           22198 non-null  object
#  7   descrip_E                        22198 non-null  object
#  8   DEMCODE                          22198 non-null  Int64
#  9   QUESTION                         22198 non-null  object
#  10  TITLE_E                          22198 non-null  object
#  11  ANSWER1                          19836 non-null  Int64
#  12  ANSWER2                          19836 non-null  Int64
#  13  ANSWER3                          19836 non-null  Int64
#  14  ANSWER4                          19836 non-null  Int64
#  15  ANSWER5                          19836 non-null  Int64
#  16  ANSWER6                          19836 non-null  Int64
#  17  ANSWER7                          19836 non-null  Int64
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  19836 non-null  Int64
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       19836 non-null  Int64
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  19836 non-null  Int64
#  21  AGREE                            19836 non-null  Int64
#  22  SCORE5                           19836 non-null  float64
#  23  SCORE100                         19836 non-null  Int64
#  24  ANSCOUNT                         19836 non-null  Int64
#  25  DEPT_E                           22198 non-null  object
#  26  INDICATORID                      22198 non-null  float64
#  27  INDICATORENG                     22198 non-null  object
#  28  SUBINDICATORID                   22198 non-null  float64
#  29  SUBINDICATORENG                  22198 non-null  object
# dtypes: Int64(14), float64(3), int64(6), object(7)
# memory usage: 5.5+ MB

# %%
# Create new column call it SUM_ANSRS, fill it with the sum of columns ANSWER1 and ANSWER2 and ANSWER3 andANSWER4 and ANSWER5 and ANSWER6 and ANSWER7
#df['SUM_ANSRS'] = df['ANSWER1'] + df['ANSWER2'] + df['ANSWER3']+ df['ANSWER4']+ df['ANSWER4']+ df['ANSWER6']+ df['ANSWER7']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22198 entries, 0 to 471967
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         22198 non-null  int64
#  1   LEVEL2ID                         22198 non-null  int64
#  2   LEVEL3ID                         22198 non-null  int64
#  3   LEVEL4ID                         22198 non-null  int64
#  4   LEVEL5ID                         22198 non-null  int64
#  5   SURVEYR                          22198 non-null  int64
#  6   BYCOND                           22198 non-null  object
#  7   descrip_E                        22198 non-null  object
#  8   DEMCODE                          22198 non-null  Int64
#  9   QUESTION                         22198 non-null  object
#  10  TITLE_E                          22198 non-null  object
#  11  ANSWER1                          19836 non-null  Int64
#  12  ANSWER2                          19836 non-null  Int64
#  13  ANSWER3                          19836 non-null  Int64
#  14  ANSWER4                          19836 non-null  Int64
#  15  ANSWER5                          19836 non-null  Int64
#  16  ANSWER6                          19836 non-null  Int64
#  17  ANSWER7                          19836 non-null  Int64
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  19836 non-null  Int64
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       19836 non-null  Int64
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  19836 non-null  Int64
#  21  AGREE                            19836 non-null  Int64
#  22  SCORE5                           19836 non-null  float64
#  23  SCORE100                         19836 non-null  Int64
#  24  ANSCOUNT                         19836 non-null  Int64
#  25  DEPT_E                           22198 non-null  object
#  26  INDICATORID                      22198 non-null  float64
#  27  INDICATORENG                     22198 non-null  object
#  28  SUBINDICATORID                   22198 non-null  float64
#  29  SUBINDICATORENG                  22198 non-null  object
# dtypes: Int64(14), float64(3), int64(6), object(7)
# memory usage: 5.5+ MB

# %%
df.head()
# Out:
#     LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR    BYCOND  \
# 0          0         0         0         0         0     2022  Q117 = 1
# 6          6         0         0         0         0     2022  Q117 = 1
# 49        70         0         0         0         0     2022  Q117 = 1
# 69         0         0         0         0         0     2020  Q117 = 1
# 75         6         0         0         0         0     2020  Q117 = 1
#
#    descrip_E  DEMCODE QUESTION  \
# 0        Man     1087      Q01
# 6        Man     1087      Q01
# 49       Man     1087      Q01
# 69       Man     1087      Q01
# 75       Man     1087      Q01
#
#                                               TITLE_E  ANSWER1  ANSWER2  \
# 0   Question 1. I have the tools, technology and e...       39       42
# 6   Question 1. I have the tools, technology and e...       37       46
# 49  Question 1. I have the tools, technology and e...       40       41
# 69  Question 1. I have the tools, technology and e...       35       45
# 75  Question 1. I have the tools, technology and e...       37       46
#
#     ANSWER3  ANSWER4  ANSWER5  ANSWER6  ANSWER7  \
# 0         5        9        5        0        0
# 6         4       10        3        0        0
# 49        5       10        4        0        0
# 69        6       11        3        0        0
# 75        6        9        2        0        0
#
#     MOST_POSITIVE_OR_LEAST_NEGATIVE  NEUTRAL_OR_MIDDLE_CATEGORY  \
# 0                                81                           5
# 6                                83                           4
# 49                               81                           5
# 69                               81                           6
# 75                               83                           6
#
#     MOST_NEGATIVE_OR_LEAST_POSITIVE  AGREE  SCORE5  SCORE100  ANSCOUNT  \
# 0                                14     81    4.02        76     69605
# 6                                13     83    4.03        76      1715
# 49                               14     81    4.04        76       530
# 69                               14     81    3.99        75     73497
# 75                               11     83    4.07        77      1613
#
#                             DEPT_E  INDICATORID INDICATORENG  SUBINDICATORID  \
# 0                   Public Service          4.0    Workplace            14.0
# 6                    Health Canada          4.0    Workplace            14.0
# 49  Public Health Agency of Canada          4.0    Workplace            14.0
# 69                  Public Service          4.0    Workplace            14.0
# 75                   Health Canada          4.0    Workplace            14.0
#
#                        SUBINDICATORENG
# 0   Physical environment and equipment
# 6   Physical environment and equipment
# 49  Physical environment and equipment
# 69  Physical environment and equipment
# 75  Physical environment and equipment

# %%
answer_cols = ["ANSWER1", "ANSWER2", "ANSWER3", "ANSWER4", "ANSWER5", "ANSWER6"]
df[answer_cols] = df[answer_cols].apply(pd.to_numeric, errors='coerce')

# %%
# CASE 1: If ANSWER3 is null
df.loc[df['ANSWER3'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1']
df.loc[df['ANSWER3'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER2']

# CASE 2: If ANSWER3 is not null and ANSWER4 is null
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].isna(), 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER2']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER3']

# CASE 3: If ANSWER3 is not null, ANSWER4 is not null, and ANSWER5 is null
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1'] + df['ANSWER2']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].isna(), 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER3']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER4']

# CASE 4: If ANSWER3, ANSWER4, ANSWER5 are not null, and ANSWER6 is null
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].notna() & df['ANSWER6'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1'] + df['ANSWER2']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].notna() & df['ANSWER6'].isna(), 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER3']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].notna() & df['ANSWER6'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER4']

# %%
df.isnull().sum()
# Out:
# LEVEL1ID                              0
# LEVEL2ID                              0
# LEVEL3ID                              0
# LEVEL4ID                              0
# LEVEL5ID                              0
# SURVEYR                               0
# BYCOND                                0
# descrip_E                             0
# DEMCODE                               0
# QUESTION                              0
# TITLE_E                               0
# ANSWER1                            2362
# ANSWER2                            2362
# ANSWER3                            2362
# ANSWER4                            2362
# ANSWER5                            2362
# ANSWER6                            2362
# ANSWER7                            2362
# MOST_POSITIVE_OR_LEAST_NEGATIVE    2362
# NEUTRAL_OR_MIDDLE_CATEGORY         2362
# MOST_NEGATIVE_OR_LEAST_POSITIVE    2362
# AGREE                              2362
# SCORE5                             2362
# SCORE100                           2362
# ANSCOUNT                           2362
# DEPT_E                                0
# INDICATORID                           0
# INDICATORENG                          0
# SUBINDICATORID                        0
# SUBINDICATORENG                       0
# dtype: int64

# %%
# export the dataset df_HC to a csv file and call it subset1_HealthCanada
df.to_csv('subset1_cleaned.csv', index=False)

# %%
# in 'QUESTION' where the Values = D56_1 change it to Q56_1
df.loc[df['QUESTION'] == 'D56_1', 'QUESTION'] = 'Q56_1'

# %%
# in 'QUESTION' where the Values = D56_2 change it to Q56_2
df.loc[df['QUESTION'] == 'D56_2', 'QUESTION'] = 'Q56_2'

# %%
# Define the columns to be set to NaN
cols_to_nullify = [
    "MOST_POSITIVE_OR_LEAST_NEGATIVE",
    "NEUTRAL_OR_MIDDLE_CATEGORY",
    "MOST_NEGATIVE_OR_LEAST_POSITIVE",
    "AGREE",
    "SCORE5",
    "SCORE100"
]

# Set the columns to NaN where QUESTIONS that doesnt have sentiment asnwers
df.loc[df['QUESTION'].isin(['Q56_1', 'Q56_2', 'Q81', 'Q83', 'Q93', 'Q95']), cols_to_nullify] = pd.NA

# %%
# Set the values where QUESTION is 'Q88'
df.loc[df['QUESTION'] == 'Q88', 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER2']
df.loc[df['QUESTION'] == 'Q88', 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER1']
df.loc[df['QUESTION'] == 'Q88', 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER3'] + df['ANSWER4']

# %%
import re

# Define the pattern to match questions like Q57, Q58, Q59, etc., including any suffix (e.g., Q58a, Q58b, etc.)
questions_pattern = r'Q(57|58|59|60|61|64|65|67|68)[a-zA-Z]?'

# Set the values where QUESTION matches the pattern
df.loc[df['QUESTION'].str.match(questions_pattern), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER2']
df.loc[df['QUESTION'].str.match(questions_pattern), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER1']

# %%
# export the dataset df_HC to a csv file and call it subset1_HealthCanada
df.to_csv('subset3_cleaned.csv', index=False)
