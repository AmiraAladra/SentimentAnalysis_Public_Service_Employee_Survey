# %%
import pandas as pd

# %%
# Import the data
data = pd.read_csv('Subset 6 - 2022_2023 PSES open dataset - with labels_Sous-ensemble 6 - Ensemble de données ouvertes du SAFF de 2022_23.csv', encoding='latin-1')

# %%
data.shape
# Out:
# (232566, 35)

# %%
# show head of the data, and show all the columns
pd.set_option('display.max_columns', None)
data.head()
# Out:
#    LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR    BYCOND  \
# 0         0         0         0         0         0     2022  Q106 = 1
# 1         1         0         0         0         0     2022  Q106 = 1
# 2         2         0         0         0         0     2022  Q106 = 1
# 3         3         0         0         0         0     2022  Q106 = 1
# 4         4         0         0         0         0     2022  Q106 = 1
#
#                                        descrip_E  \
# 0  Language requirement of position  - Bilingual
# 1  Language requirement of position  - Bilingual
# 2  Language requirement of position  - Bilingual
# 3  Language requirement of position  - Bilingual
# 4  Language requirement of position  - Bilingual
#
#                                      descrip_F  DEMCODE QUESTION  \
# 0  Exigences linguistiques du poste - Bilingue     1017      Q01
# 1  Exigences linguistiques du poste - Bilingue     1017      Q01
# 2  Exigences linguistiques du poste - Bilingue     1017      Q01
# 3  Exigences linguistiques du poste - Bilingue     1017      Q01
# 4  Exigences linguistiques du poste - Bilingue     1017      Q01
#
#                                              TITLE_E  \
# 0  Question 1. I have the tools, technology and e...
# 1  Question 1. I have the tools, technology and e...
# 2  Question 1. I have the tools, technology and e...
# 3  Question 1. I have the tools, technology and e...
# 4  Question 1. I have the tools, technology and e...
#
#                                              TITLE_F ANSWER1 ANSWER2 ANSWER3  \
# 0  Question 1. Je dispose des outils, de la techn...      43      42       4
# 1  Question 1. Je dispose des outils, de la techn...      55      37       3
# 2  Question 1. Je dispose des outils, de la techn...      52      37       3
# 3  Question 1. Je dispose des outils, de la techn...      33      44       6
# 4  Question 1. Je dispose des outils, de la techn...      28      49       6
#
#   ANSWER4 ANSWER5 ANSWER6 ANSWER7 MOST_POSITIVE_OR_LEAST_NEGATIVE  \
# 0       8       3       0       0                              84
# 1       4       1       0       0                              92
# 2       6       2       0       0                              89
# 3      12       5       0       0                              77
# 4      12       6       0       0                              76
#
#   NEUTRAL_OR_MIDDLE_CATEGORY MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5  \
# 0                          4                              12    84   4.12
# 1                          3                               5    92    4.4
# 2                          3                               8    89    4.3
# 3                          6                              17    77   3.87
# 4                          6                              18    76   3.81
#
#   SCORE100  ANSCOUNT                                    DEPT_E  \
# 0       78   80465.0                            Public Service
# 1       85    9900.0                     Canada Revenue Agency
# 2       83    7410.0  Employment and Social Development Canada
# 3       72    4510.0            Department of National Defence
# 4       70    1905.0               Correctional Service Canada
#
#                                   DEPT_F  INDICATORID INDICATORENG  \
# 0                      Fonction publique          4.0    Workplace
# 1             Agence du revenu du Canada          4.0    Workplace
# 2  Emploi et Développement social Canada          4.0    Workplace
# 3      Ministère de la Défense nationale          4.0    Workplace
# 4           Service correctionnel Canada          4.0    Workplace
#
#         INDICATORFRA  SUBINDICATORID                     SUBINDICATORENG  \
# 0  Milieu de travail            14.0  Physical environment and equipment
# 1  Milieu de travail            14.0  Physical environment and equipment
# 2  Milieu de travail            14.0  Physical environment and equipment
# 3  Milieu de travail            14.0  Physical environment and equipment
# 4  Milieu de travail            14.0  Physical environment and equipment
#
#                         SUBINDICATORFRA
# 0  Environnement physique et équipement
# 1  Environnement physique et équipement
# 2  Environnement physique et équipement
# 3  Environnement physique et équipement
# 4  Environnement physique et équipement

# %%
data.tail()
# Out:
#         LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR    BYCOND  \
# 232561        50         0         0         0         0     2022  Q115 = 1
# 232562        52         0         0         0         0     2022  Q115 = 1
# 232563        53         0         0         0         0     2022  Q115 = 1
# 232564        54         0         0         0         0     2022  Q115 = 1
# 232565        56         0         0         0         0     2022  Q115 = 1
#
#                                                 descrip_E  \
# 232561  The bilingual region of Montréal (the counties...
# 232562  The bilingual region of Montréal (the counties...
# 232563  The bilingual region of Montréal (the counties...
# 232564  The bilingual region of Montréal (the counties...
# 232565  The bilingual region of Montréal (the counties...
#
#                                                 descrip_F  DEMCODE QUESTION  \
# 232561  La région bilingue de Montréal (les comtés de ...     1073      Q44
# 232562  La région bilingue de Montréal (les comtés de ...     1073      Q44
# 232563  La région bilingue de Montréal (les comtés de ...     1073      Q44
# 232564  La région bilingue de Montréal (les comtés de ...     1073      Q44
# 232565  La région bilingue de Montréal (les comtés de ...     1073      Q44
#
#                                                   TITLE_E  \
# 232561  Question 44. I believe I have opportunities fo...
# 232562  Question 44. I believe I have opportunities fo...
# 232563  Question 44. I believe I have opportunities fo...
# 232564  Question 44. I believe I have opportunities fo...
# 232565  Question 44. I believe I have opportunities fo...
#
#                                                   TITLE_F ANSWER1 ANSWER2  \
# 232561  Question 44. J'estime avoir des possibilités d...      14      23
# 232562  Question 44. J'estime avoir des possibilités d...      31      40
# 232563  Question 44. J'estime avoir des possibilités d...      16      37
# 232564  Question 44. J'estime avoir des possibilités d...       X       X
# 232565  Question 44. J'estime avoir des possibilités d...       X     NaN
#
#        ANSWER3 ANSWER4 ANSWER5 ANSWER6 ANSWER7  \
# 232561      19      19      19       4       2
# 232562      20       4       4       0       0
# 232563      19      17       7       4       0
# 232564       X       X       X       X       X
# 232565     NaN     NaN     NaN     NaN     NaN
#
#        MOST_POSITIVE_OR_LEAST_NEGATIVE NEUTRAL_OR_MIDDLE_CATEGORY  \
# 232561                              40                         20
# 232562                              71                         20
# 232563                              55                         19
# 232564                               X                          X
# 232565                             NaN                        NaN
#
#        MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5 SCORE100  ANSCOUNT  \
# 232561                              41    40   2.94       49     330.0
# 232562                               9    71   3.89       72      20.0
# 232563                              25    55   3.39       60      30.0
# 232564                               X     X      X        X       NaN
# 232565                             NaN   NaN    NaN      NaN       NaN
#
#                                          DEPT_E  \
# 232561         National Research Council Canada
# 232562  Office of the Auditor General of Canada
# 232563                     Public Safety Canada
# 232564           Canadian Transportation Agency
# 232565                                      NaN
#
#                                           DEPT_F  INDICATORID INDICATORENG  \
# 232561     Conseil national de recherches Canada          3.0    Workforce
# 232562  Bureau du vérificateur général du Canada          3.0    Workforce
# 232563                  Sécurité publique Canada          3.0    Workforce
# 232564           Office des transports du Canada          3.0    Workforce
# 232565                                       NaN          NaN          NaN
#
#        INDICATORFRA  SUBINDICATORID          SUBINDICATORENG  \
# 232561     Effectif             5.0  Job fit and development
# 232562     Effectif             5.0  Job fit and development
# 232563     Effectif             5.0  Job fit and development
# 232564     Effectif             5.0  Job fit and development
# 232565          NaN             NaN                      NaN
#
#                                           SUBINDICATORFRA
# 232561  Compatibilité entre la personne et l'emploi et...
# 232562  Compatibilité entre la personne et l'emploi et...
# 232563  Compatibilité entre la personne et l'emploi et...
# 232564  Compatibilité entre la personne et l'emploi et...
# 232565                                                NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232566 entries, 0 to 232565
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   LEVEL1ID                         232566 non-null  int64
#  1   LEVEL2ID                         232566 non-null  int64
#  2   LEVEL3ID                         232566 non-null  int64
#  3   LEVEL4ID                         232566 non-null  int64
#  4   LEVEL5ID                         232566 non-null  int64
#  5   SURVEYR                          232566 non-null  int64
#  6   BYCOND                           232566 non-null  object
#  7   descrip_E                        232566 non-null  object
#  8   descrip_F                        232566 non-null  object
#  9   DEMCODE                          232566 non-null  int64
#  10  QUESTION                         232566 non-null  object
#  11  TITLE_E                          232566 non-null  object
#  12  TITLE_F                          232566 non-null  object
#  13  ANSWER1                          192519 non-null  object
#  14  ANSWER2                          192518 non-null  object
#  15  ANSWER3                          192518 non-null  object
#  16  ANSWER4                          192518 non-null  object
#  17  ANSWER5                          192518 non-null  object
#  18  ANSWER6                          192518 non-null  object
#  19  ANSWER7                          192518 non-null  object
#  20  MOST_POSITIVE_OR_LEAST_NEGATIVE  192518 non-null  object
#  21  NEUTRAL_OR_MIDDLE_CATEGORY       192518 non-null  object
#  22  MOST_NEGATIVE_OR_LEAST_POSITIVE  192518 non-null  object
#  23  AGREE                            192518 non-null  object
#  24  SCORE5                           192518 non-null  object
#  25  SCORE100                         192518 non-null  object
#  26  ANSCOUNT                         170466 non-null  float64
#  27  DEPT_E                           232565 non-null  object
#  28  DEPT_F                           232565 non-null  object
#  29  INDICATORID                      232565 non-null  float64
#  30  INDICATORENG                     232565 non-null  object
#  31  INDICATORFRA                     232565 non-null  object
#  32  SUBINDICATORID                   232565 non-null  float64
#  33  SUBINDICATORENG                  232565 non-null  object
#  34  SUBINDICATORFRA                  232565 non-null  object
# dtypes: float64(3), int64(7), object(25)
# memory usage: 62.1+ MB

# %%
# dropping the french columns: descrip_F,TITLE_F ,DEPT_F ,SUBINDICATORFRA,INDICATORFRA AND SAVE IT IN A NEW datafarme call ot df_HC
df = data.drop(columns=['descrip_F', 'TITLE_F', 'DEPT_F', 'SUBINDICATORFRA', 'INDICATORFRA'])

# %%
# extract the df to be equal only where DEPT_E = 'Health Canada'or 'Public Service' or'Public Health Agency of Canada'
df = df[df['DEPT_E'].isin(['Health Canada', 'Public Service', 'Public Health Agency of Canada'])]
df.head()
# Out:
#     LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR    BYCOND  \
# 0          0         0         0         0         0     2022  Q106 = 1
# 6          6         0         0         0         0     2022  Q106 = 1
# 49        70         0         0         0         0     2022  Q106 = 1
# 69         0         0         0         0         0     2022  Q106 = 2
# 75         6         0         0         0         0     2022  Q106 = 2
#
#                                             descrip_E  DEMCODE QUESTION  \
# 0       Language requirement of position  - Bilingual     1017      Q01
# 6       Language requirement of position  - Bilingual     1017      Q01
# 49      Language requirement of position  - Bilingual     1017      Q01
# 69  Language requirement of position  - Unilingual...     1018      Q01
# 75  Language requirement of position  - Unilingual...     1018      Q01
#
#                                               TITLE_E ANSWER1 ANSWER2 ANSWER3  \
# 0   Question 1. I have the tools, technology and e...      43      42       4
# 6   Question 1. I have the tools, technology and e...      36      45       4
# 49  Question 1. I have the tools, technology and e...      33      48       4
# 69  Question 1. I have the tools, technology and e...      43      41       3
# 75  Question 1. I have the tools, technology and e...      40      45       3
#
#    ANSWER4 ANSWER5 ANSWER6 ANSWER7 MOST_POSITIVE_OR_LEAST_NEGATIVE  \
# 0        8       3       0       0                              84
# 6       11       4       0       0                              81
# 49      10       4       0       0                              81
# 69       9       4       0       0                              83
# 75       9       3       0       0                              85
#
#    NEUTRAL_OR_MIDDLE_CATEGORY MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5  \
# 0                           4                              12    84   4.12
# 6                           4                              15    81   3.98
# 49                          4                              15    81   3.95
# 69                          3                              13    83   4.09
# 75                          3                              12    85    4.1
#
#    SCORE100  ANSCOUNT                          DEPT_E  INDICATORID  \
# 0        78   80465.0                  Public Service          4.0
# 6        75    2580.0                   Health Canada          4.0
# 49       74     945.0  Public Health Agency of Canada          4.0
# 69       77   79140.0                  Public Service          4.0
# 75       78    2455.0                   Health Canada          4.0
#
#    INDICATORENG  SUBINDICATORID                     SUBINDICATORENG
# 0     Workplace            14.0  Physical environment and equipment
# 6     Workplace            14.0  Physical environment and equipment
# 49    Workplace            14.0  Physical environment and equipment
# 69    Workplace            14.0  Physical environment and equipment
# 75    Workplace            14.0  Physical environment and equipment

# %%
df.shape
# Out:
# (12728, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12728 entries, 0 to 232526
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         12728 non-null  int64
#  1   LEVEL2ID                         12728 non-null  int64
#  2   LEVEL3ID                         12728 non-null  int64
#  3   LEVEL4ID                         12728 non-null  int64
#  4   LEVEL5ID                         12728 non-null  int64
#  5   SURVEYR                          12728 non-null  int64
#  6   BYCOND                           12728 non-null  object
#  7   descrip_E                        12728 non-null  object
#  8   DEMCODE                          12728 non-null  int64
#  9   QUESTION                         12728 non-null  object
#  10  TITLE_E                          12728 non-null  object
#  11  ANSWER1                          11257 non-null  object
#  12  ANSWER2                          11257 non-null  object
#  13  ANSWER3                          11257 non-null  object
#  14  ANSWER4                          11257 non-null  object
#  15  ANSWER5                          11257 non-null  object
#  16  ANSWER6                          11257 non-null  object
#  17  ANSWER7                          11257 non-null  object
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  11257 non-null  object
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       11257 non-null  object
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  11257 non-null  object
#  21  AGREE                            11257 non-null  object
#  22  SCORE5                           11257 non-null  object
#  23  SCORE100                         11257 non-null  object
#  24  ANSCOUNT                         10574 non-null  float64
#  25  DEPT_E                           12728 non-null  object
#  26  INDICATORID                      12728 non-null  float64
#  27  INDICATORENG                     12728 non-null  object
#  28  SUBINDICATORID                   12728 non-null  float64
#  29  SUBINDICATORENG                  12728 non-null  object
# dtypes: float64(3), int64(7), object(20)
# memory usage: 3.0+ MB

# %%
# find the null values in the df
df.isnull().sum()
# Out:
# LEVEL1ID                              0
# LEVEL2ID                              0
# LEVEL3ID                              0
# LEVEL4ID                              0
# LEVEL5ID                              0
# SURVEYR                               0
# BYCOND                                0
# descrip_E                             0
# DEMCODE                               0
# QUESTION                              0
# TITLE_E                               0
# ANSWER1                            1471
# ANSWER2                            1471
# ANSWER3                            1471
# ANSWER4                            1471
# ANSWER5                            1471
# ANSWER6                            1471
# ANSWER7                            1471
# MOST_POSITIVE_OR_LEAST_NEGATIVE    1471
# NEUTRAL_OR_MIDDLE_CATEGORY         1471
# MOST_NEGATIVE_OR_LEAST_POSITIVE    1471
# AGREE                              1471
# SCORE5                             1471
# SCORE100                           1471
# ANSCOUNT                           2154
# DEPT_E                                0
# INDICATORID                           0
# INDICATORENG                          0
# SUBINDICATORID                        0
# SUBINDICATORENG                       0
# dtype: int64

# %%
# records where ANSWER1 = 'X'
df[df['ANSWER3'] == 'X']
# Out:
#         LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR     BYCOND  \
# 1279           6         0         0         0         0     2022   Q114 = 6
# 1295          70         0         0         0         0     2022   Q114 = 6
# 1949           6         0         0         0         0     2022  Q114 = 13
# 1969          70         0         0         0         0     2022  Q114 = 13
# 2015           6         0         0         0         0     2022  Q114 = 14
# ...          ...       ...       ...       ...       ...      ...        ...
# 232140         6         0         0         0         0     2022  Q114 = 13
# 232160        70         0         0         0         0     2022  Q114 = 13
# 232262         6         0         0         0         0     2022  Q114 = 14
# 232404         6         0         0         0         0     2022  Q114 = 15
# 232428        70         0         0         0         0     2022  Q114 = 15
#
#                         descrip_E  DEMCODE QUESTION  \
# 1279                        Yukon     1063      Q01
# 1295                        Yukon     1063      Q01
# 1949         Prince Edward Island     1070      Q01
# 1969         Prince Edward Island     1070      Q01
# 2015    Newfoundland and Labrador     1071      Q01
# ...                           ...      ...      ...
# 232140       Prince Edward Island     1070      Q44
# 232160       Prince Edward Island     1070      Q44
# 232262  Newfoundland and Labrador     1071      Q44
# 232404          Outside of Canada     1072      Q44
# 232428          Outside of Canada     1072      Q44
#
#                                                   TITLE_E ANSWER1 ANSWER2  \
# 1279    Question 1. I have the tools, technology and e...       X       X
# 1295    Question 1. I have the tools, technology and e...       X       X
# 1949    Question 1. I have the tools, technology and e...       X       X
# 1969    Question 1. I have the tools, technology and e...       X       X
# 2015    Question 1. I have the tools, technology and e...       X       X
# ...                                                   ...     ...     ...
# 232140  Question 44. I believe I have opportunities fo...       X       X
# 232160  Question 44. I believe I have opportunities fo...       X       X
# 232262  Question 44. I believe I have opportunities fo...       X       X
# 232404  Question 44. I believe I have opportunities fo...       X       X
# 232428  Question 44. I believe I have opportunities fo...       X       X
#
#        ANSWER3 ANSWER4 ANSWER5 ANSWER6 ANSWER7  \
# 1279         X       X       X       X       X
# 1295         X       X       X       X       X
# 1949         X       X       X       X       X
# 1969         X       X       X       X       X
# 2015         X       X       X       X       X
# ...        ...     ...     ...     ...     ...
# 232140       X       X       X       X       X
# 232160       X       X       X       X       X
# 232262       X       X       X       X       X
# 232404       X       X       X       X       X
# 232428       X       X       X       X       X
#
#        MOST_POSITIVE_OR_LEAST_NEGATIVE NEUTRAL_OR_MIDDLE_CATEGORY  \
# 1279                                 X                          X
# 1295                                 X                          X
# 1949                                 X                          X
# 1969                                 X                          X
# 2015                                 X                          X
# ...                                ...                        ...
# 232140                               X                          X
# 232160                               X                          X
# 232262                               X                          X
# 232404                               X                          X
# 232428                               X                          X
#
#        MOST_NEGATIVE_OR_LEAST_POSITIVE AGREE SCORE5 SCORE100  ANSCOUNT  \
# 1279                                 X     X      X        X       NaN
# 1295                                 X     X      X        X       NaN
# 1949                                 X     X      X        X       NaN
# 1969                                 X     X      X        X       NaN
# 2015                                 X     X      X        X       NaN
# ...                                ...   ...    ...      ...       ...
# 232140                               X     X      X        X       NaN
# 232160                               X     X      X        X       NaN
# 232262                               X     X      X        X       NaN
# 232404                               X     X      X        X       NaN
# 232428                               X     X      X        X       NaN
#
#                                 DEPT_E  INDICATORID INDICATORENG  \
# 1279                     Health Canada          4.0    Workplace
# 1295    Public Health Agency of Canada          4.0    Workplace
# 1949                     Health Canada          4.0    Workplace
# 1969    Public Health Agency of Canada          4.0    Workplace
# 2015                     Health Canada          4.0    Workplace
# ...                                ...          ...          ...
# 232140                   Health Canada          3.0    Workforce
# 232160  Public Health Agency of Canada          3.0    Workforce
# 232262                   Health Canada          3.0    Workforce
# 232404                   Health Canada          3.0    Workforce
# 232428  Public Health Agency of Canada          3.0    Workforce
#
#         SUBINDICATORID                     SUBINDICATORENG
# 1279              14.0  Physical environment and equipment
# 1295              14.0  Physical environment and equipment
# 1949              14.0  Physical environment and equipment
# 1969              14.0  Physical environment and equipment
# 2015              14.0  Physical environment and equipment
# ...                ...                                 ...
# 232140             5.0             Job fit and development
# 232160             5.0             Job fit and development
# 232262             5.0             Job fit and development
# 232404             5.0             Job fit and development
# 232428             5.0             Job fit and development
#
# [683 rows x 30 columns]

# %%
# records where ANSWER3 or ANSWER4 or ANSWER5 or ANSWER6 or ANSWER7 = '9999'
df[(df['ANSWER3'] == '9999') | (df['ANSWER4'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER7'] == '9999')]
# Out:
# Empty DataFrame
# Columns: [LEVEL1ID, LEVEL2ID, LEVEL3ID, LEVEL4ID, LEVEL5ID, SURVEYR, BYCOND, descrip_E, DEMCODE, QUESTION, TITLE_E, ANSWER1, ANSWER2, ANSWER3, ANSWER4, ANSWER5, ANSWER6, ANSWER7, MOST_POSITIVE_OR_LEAST_NEGATIVE, NEUTRAL_OR_MIDDLE_CATEGORY, MOST_NEGATIVE_OR_LEAST_POSITIVE, AGREE, SCORE5, SCORE100, ANSCOUNT, DEPT_E, INDICATORID, INDICATORENG, SUBINDICATORID, SUBINDICATORENG]
# Index: []

# %%
# Replace and value in the dataset that equal to '9999' with NaN
df.replace([9999, '9999'], pd.NA, inplace=True)

# %%
# records where ANSWER3 or ANSWER4 or ANSWER5 or ANSWER6 or ANSWER7 = '9999'
df[(df['ANSWER3'] == '9999') | (df['ANSWER4'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER5'] == '9999') |(df['ANSWER7'] == '9999')]
# Out:
# Empty DataFrame
# Columns: [LEVEL1ID, LEVEL2ID, LEVEL3ID, LEVEL4ID, LEVEL5ID, SURVEYR, BYCOND, descrip_E, DEMCODE, QUESTION, TITLE_E, ANSWER1, ANSWER2, ANSWER3, ANSWER4, ANSWER5, ANSWER6, ANSWER7, MOST_POSITIVE_OR_LEAST_NEGATIVE, NEUTRAL_OR_MIDDLE_CATEGORY, MOST_NEGATIVE_OR_LEAST_POSITIVE, AGREE, SCORE5, SCORE100, ANSCOUNT, DEPT_E, INDICATORID, INDICATORENG, SUBINDICATORID, SUBINDICATORENG]
# Index: []

# %%
# Replace and value in the dataset that equal to 'X' with NaN
df = df.replace('X', pd.NA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12728 entries, 0 to 232526
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         12728 non-null  int64
#  1   LEVEL2ID                         12728 non-null  int64
#  2   LEVEL3ID                         12728 non-null  int64
#  3   LEVEL4ID                         12728 non-null  int64
#  4   LEVEL5ID                         12728 non-null  int64
#  5   SURVEYR                          12728 non-null  int64
#  6   BYCOND                           12728 non-null  object
#  7   descrip_E                        12728 non-null  object
#  8   DEMCODE                          12728 non-null  int64
#  9   QUESTION                         12728 non-null  object
#  10  TITLE_E                          12728 non-null  object
#  11  ANSWER1                          10574 non-null  object
#  12  ANSWER2                          10574 non-null  object
#  13  ANSWER3                          10574 non-null  object
#  14  ANSWER4                          10574 non-null  object
#  15  ANSWER5                          10574 non-null  object
#  16  ANSWER6                          10574 non-null  object
#  17  ANSWER7                          10574 non-null  object
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  10574 non-null  object
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       10574 non-null  object
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  10574 non-null  object
#  21  AGREE                            10574 non-null  object
#  22  SCORE5                           10574 non-null  object
#  23  SCORE100                         10574 non-null  object
#  24  ANSCOUNT                         10574 non-null  float64
#  25  DEPT_E                           12728 non-null  object
#  26  INDICATORID                      12728 non-null  float64
#  27  INDICATORENG                     12728 non-null  object
#  28  SUBINDICATORID                   12728 non-null  float64
#  29  SUBINDICATORENG                  12728 non-null  object
# dtypes: float64(3), int64(7), object(20)
# memory usage: 3.0+ MB

# %%
# Change the data type of BYCOND to object
df['BYCOND'] = df['BYCOND'].astype(object)

# %%
# Change the data type of DEMCODE to int
df['DEMCODE'] = df['DEMCODE'].astype('Int64')

# %%
answers_cols = ['ANSWER1', 'ANSWER2', 'ANSWER3', 'ANSWER4', 'ANSWER5', 'ANSWER6', 'ANSWER7']

# %%
df[answers_cols] = df[answers_cols].apply(pd.to_numeric, errors='coerce')

# %%
# Change the data type of answers columns  to integer
df[answers_cols] = df[answers_cols].astype('Int64')

# %%
# Select the desired columns using a list
cols_to_convert = ['MOST_POSITIVE_OR_LEAST_NEGATIVE', 'NEUTRAL_OR_MIDDLE_CATEGORY', 'MOST_NEGATIVE_OR_LEAST_POSITIVE','AGREE','SCORE5','SCORE100','ANSCOUNT']
# Apply pd.to_numeric to the selected columns
df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
# Change the data type of columns ANSWER1 and ANSWER2 to integer
df[cols_to_convert] = df[cols_to_convert].astype(pd.Int64Dtype(),errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12728 entries, 0 to 232526
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         12728 non-null  int64
#  1   LEVEL2ID                         12728 non-null  int64
#  2   LEVEL3ID                         12728 non-null  int64
#  3   LEVEL4ID                         12728 non-null  int64
#  4   LEVEL5ID                         12728 non-null  int64
#  5   SURVEYR                          12728 non-null  int64
#  6   BYCOND                           12728 non-null  object
#  7   descrip_E                        12728 non-null  object
#  8   DEMCODE                          12728 non-null  Int64
#  9   QUESTION                         12728 non-null  object
#  10  TITLE_E                          12728 non-null  object
#  11  ANSWER1                          10574 non-null  Int64
#  12  ANSWER2                          10574 non-null  Int64
#  13  ANSWER3                          10574 non-null  Int64
#  14  ANSWER4                          10574 non-null  Int64
#  15  ANSWER5                          10574 non-null  Int64
#  16  ANSWER6                          10574 non-null  Int64
#  17  ANSWER7                          10574 non-null  Int64
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  10574 non-null  Int64
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       10574 non-null  Int64
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  10574 non-null  Int64
#  21  AGREE                            10574 non-null  Int64
#  22  SCORE5                           10574 non-null  float64
#  23  SCORE100                         10574 non-null  Int64
#  24  ANSCOUNT                         10574 non-null  Int64
#  25  DEPT_E                           12728 non-null  object
#  26  INDICATORID                      12728 non-null  float64
#  27  INDICATORENG                     12728 non-null  object
#  28  SUBINDICATORID                   12728 non-null  float64
#  29  SUBINDICATORENG                  12728 non-null  object
# dtypes: Int64(14), float64(3), int64(6), object(7)
# memory usage: 3.2+ MB

# %%
# Create new column call it SUM_ANSRS, fill it with the sum of columns ANSWER1 and ANSWER2 and ANSWER3 andANSWER4 and ANSWER5 and ANSWER6 and ANSWER7
#df['SUM_ANSRS'] = df['ANSWER1'] + df['ANSWER2'] + df['ANSWER3']+ df['ANSWER4']+ df['ANSWER4']+ df['ANSWER6']+ df['ANSWER7']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12728 entries, 0 to 232526
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LEVEL1ID                         12728 non-null  int64
#  1   LEVEL2ID                         12728 non-null  int64
#  2   LEVEL3ID                         12728 non-null  int64
#  3   LEVEL4ID                         12728 non-null  int64
#  4   LEVEL5ID                         12728 non-null  int64
#  5   SURVEYR                          12728 non-null  int64
#  6   BYCOND                           12728 non-null  object
#  7   descrip_E                        12728 non-null  object
#  8   DEMCODE                          12728 non-null  Int64
#  9   QUESTION                         12728 non-null  object
#  10  TITLE_E                          12728 non-null  object
#  11  ANSWER1                          10574 non-null  Int64
#  12  ANSWER2                          10574 non-null  Int64
#  13  ANSWER3                          10574 non-null  Int64
#  14  ANSWER4                          10574 non-null  Int64
#  15  ANSWER5                          10574 non-null  Int64
#  16  ANSWER6                          10574 non-null  Int64
#  17  ANSWER7                          10574 non-null  Int64
#  18  MOST_POSITIVE_OR_LEAST_NEGATIVE  10574 non-null  Int64
#  19  NEUTRAL_OR_MIDDLE_CATEGORY       10574 non-null  Int64
#  20  MOST_NEGATIVE_OR_LEAST_POSITIVE  10574 non-null  Int64
#  21  AGREE                            10574 non-null  Int64
#  22  SCORE5                           10574 non-null  float64
#  23  SCORE100                         10574 non-null  Int64
#  24  ANSCOUNT                         10574 non-null  Int64
#  25  DEPT_E                           12728 non-null  object
#  26  INDICATORID                      12728 non-null  float64
#  27  INDICATORENG                     12728 non-null  object
#  28  SUBINDICATORID                   12728 non-null  float64
#  29  SUBINDICATORENG                  12728 non-null  object
# dtypes: Int64(14), float64(3), int64(6), object(7)
# memory usage: 3.2+ MB

# %%
df.head()
# Out:
#     LEVEL1ID  LEVEL2ID  LEVEL3ID  LEVEL4ID  LEVEL5ID  SURVEYR    BYCOND  \
# 0          0         0         0         0         0     2022  Q106 = 1
# 6          6         0         0         0         0     2022  Q106 = 1
# 49        70         0         0         0         0     2022  Q106 = 1
# 69         0         0         0         0         0     2022  Q106 = 2
# 75         6         0         0         0         0     2022  Q106 = 2
#
#                                             descrip_E  DEMCODE QUESTION  \
# 0       Language requirement of position  - Bilingual     1017      Q01
# 6       Language requirement of position  - Bilingual     1017      Q01
# 49      Language requirement of position  - Bilingual     1017      Q01
# 69  Language requirement of position  - Unilingual...     1018      Q01
# 75  Language requirement of position  - Unilingual...     1018      Q01
#
#                                               TITLE_E  ANSWER1  ANSWER2  \
# 0   Question 1. I have the tools, technology and e...       43       42
# 6   Question 1. I have the tools, technology and e...       36       45
# 49  Question 1. I have the tools, technology and e...       33       48
# 69  Question 1. I have the tools, technology and e...       43       41
# 75  Question 1. I have the tools, technology and e...       40       45
#
#     ANSWER3  ANSWER4  ANSWER5  ANSWER6  ANSWER7  \
# 0         4        8        3        0        0
# 6         4       11        4        0        0
# 49        4       10        4        0        0
# 69        3        9        4        0        0
# 75        3        9        3        0        0
#
#     MOST_POSITIVE_OR_LEAST_NEGATIVE  NEUTRAL_OR_MIDDLE_CATEGORY  \
# 0                                84                           4
# 6                                81                           4
# 49                               81                           4
# 69                               83                           3
# 75                               85                           3
#
#     MOST_NEGATIVE_OR_LEAST_POSITIVE  AGREE  SCORE5  SCORE100  ANSCOUNT  \
# 0                                12     84    4.12        78     80465
# 6                                15     81    3.98        75      2580
# 49                               15     81    3.95        74       945
# 69                               13     83    4.09        77     79140
# 75                               12     85    4.10        78      2455
#
#                             DEPT_E  INDICATORID INDICATORENG  SUBINDICATORID  \
# 0                   Public Service          4.0    Workplace            14.0
# 6                    Health Canada          4.0    Workplace            14.0
# 49  Public Health Agency of Canada          4.0    Workplace            14.0
# 69                  Public Service          4.0    Workplace            14.0
# 75                   Health Canada          4.0    Workplace            14.0
#
#                        SUBINDICATORENG
# 0   Physical environment and equipment
# 6   Physical environment and equipment
# 49  Physical environment and equipment
# 69  Physical environment and equipment
# 75  Physical environment and equipment

# %%
answer_cols = ["ANSWER1", "ANSWER2", "ANSWER3", "ANSWER4", "ANSWER5", "ANSWER6"]
df[answer_cols] = df[answer_cols].apply(pd.to_numeric, errors='coerce')

# %%
# CASE 1: If ANSWER3 is null
df.loc[df['ANSWER3'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1']
df.loc[df['ANSWER3'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER2']

# CASE 2: If ANSWER3 is not null and ANSWER4 is null
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].isna(), 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER2']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER3']

# CASE 3: If ANSWER3 is not null, ANSWER4 is not null, and ANSWER5 is null
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1'] + df['ANSWER2']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].isna(), 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER3']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER4']

# CASE 4: If ANSWER3, ANSWER4, ANSWER5 are not null, and ANSWER6 is null
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].notna() & df['ANSWER6'].isna(), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER1'] + df['ANSWER2']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].notna() & df['ANSWER6'].isna(), 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER3']
df.loc[df['ANSWER3'].notna() & df['ANSWER4'].notna() & df['ANSWER5'].notna() & df['ANSWER6'].isna(), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER4']

# %%
df.isnull().sum()
# Out:
# LEVEL1ID                              0
# LEVEL2ID                              0
# LEVEL3ID                              0
# LEVEL4ID                              0
# LEVEL5ID                              0
# SURVEYR                               0
# BYCOND                                0
# descrip_E                             0
# DEMCODE                               0
# QUESTION                              0
# TITLE_E                               0
# ANSWER1                            2154
# ANSWER2                            2154
# ANSWER3                            2154
# ANSWER4                            2154
# ANSWER5                            2154
# ANSWER6                            2154
# ANSWER7                            2154
# MOST_POSITIVE_OR_LEAST_NEGATIVE    2154
# NEUTRAL_OR_MIDDLE_CATEGORY         2154
# MOST_NEGATIVE_OR_LEAST_POSITIVE    2154
# AGREE                              2154
# SCORE5                             2154
# SCORE100                           2154
# ANSCOUNT                           2154
# DEPT_E                                0
# INDICATORID                           0
# INDICATORENG                          0
# SUBINDICATORID                        0
# SUBINDICATORENG                       0
# dtype: int64

# %%
# export the dataset df_HC to a csv file and call it subset1_HealthCanada
df.to_csv('subset1_cleaned.csv', index=False)

# %%
# in 'QUESTION' where the Values = D56_1 change it to Q56_1
df.loc[df['QUESTION'] == 'D56_1', 'QUESTION'] = 'Q56_1'

# %%
# in 'QUESTION' where the Values = D56_2 change it to Q56_2
df.loc[df['QUESTION'] == 'D56_2', 'QUESTION'] = 'Q56_2'

# %%
# Define the columns to be set to NaN
cols_to_nullify = [
    "MOST_POSITIVE_OR_LEAST_NEGATIVE",
    "NEUTRAL_OR_MIDDLE_CATEGORY",
    "MOST_NEGATIVE_OR_LEAST_POSITIVE",
    "AGREE",
    "SCORE5",
    "SCORE100"
]

# Set the columns to NaN where QUESTIONS that doesnt have sentiment asnwers
df.loc[df['QUESTION'].isin(['Q56_1', 'Q56_2', 'Q81', 'Q83', 'Q93', 'Q95']), cols_to_nullify] = pd.NA

# %%
# Set the values where QUESTION is 'Q88'
df.loc[df['QUESTION'] == 'Q88', 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER2']
df.loc[df['QUESTION'] == 'Q88', 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER1']
df.loc[df['QUESTION'] == 'Q88', 'NEUTRAL_OR_MIDDLE_CATEGORY'] = df['ANSWER3'] + df['ANSWER4']

# %%
import re

# Define the pattern to match questions like Q57, Q58, Q59, etc., including any suffix (e.g., Q58a, Q58b, etc.)
questions_pattern = r'Q(57|58|59|60|61|64|65|67|68)[a-zA-Z]?'

# Set the values where QUESTION matches the pattern
df.loc[df['QUESTION'].str.match(questions_pattern), 'MOST_POSITIVE_OR_LEAST_NEGATIVE'] = df['ANSWER2']
df.loc[df['QUESTION'].str.match(questions_pattern), 'MOST_NEGATIVE_OR_LEAST_POSITIVE'] = df['ANSWER1']

# %%
# export the dataset df_HC to a csv file and call it subset1_HealthCanada
df.to_csv('subset6_cleaned.csv', index=False)
